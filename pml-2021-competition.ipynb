# %%
import time

import pandas as pd
import numpy as np
np.random.seed(0)

import matplotlib.pyplot as plot
import seaborn as sn


from sklearn.metrics import mean_absolute_error


from sklearn.model_selection import train_test_split

from functools import partial
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials

# models
import xgboost as xgb

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/pmlprices-raw-data/4property.train.pkl
# /kaggle/input/pmlprices-raw-data/4property.test.pkl

# %%
train = pd.read_pickle('/kaggle/input/pmlprices-raw-data/4property.train.pkl')
test = pd.read_pickle('/kaggle/input/pmlprices-raw-data/4property.test.pkl')

# %%
# # to pickle4:
# train.to_pickle('4property.train.pkl', protocol=4)
# test.to_pickle('4property.test.pkl', protocol=4)

# %%
pd.set_option('max_columns', 100)
pd.set_option('max_info_columns', 500)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45694 entries, 0 to 45693
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   breadcrumbs                 45694 non-null  object
#  1   date                        45694 non-null  object
#  2   geo_block                   45694 non-null  object
#  3   owner                       45694 non-null  object
#  4   price                       45694 non-null  float64
#  5   Security:                   26186 non-null  object
#  6   Building type:              45520 non-null  object
#  7   Object type:                45686 non-null  object
#  8   Ad type:                    45686 non-null  object
#  9   Commission agent:           45371 non-null  object
#  10  Construction phase:         35768 non-null  object
#  11  Housing class:              35768 non-null  object
#  12  Elevator:                   26821 non-null  object
#  13  Bathroom type:              12335 non-null  object
#  14  Balcony type:               11231 non-null  object
#  15  Mortgage possible:          19101 non-null  object
#  16  The view from the window:   14758 non-null  object
#  17  Garbage chute:              19315 non-null  object
#  18  Repair:                     6108 non-null   object
#  19  Fridge:                     324 non-null    object
#  20  Phone:                      680 non-null    object
#  21  Furniture:                  326 non-null    object
#  22  Free layout:                871 non-null    object
#  23  It is possible to bargain:  308 non-null    object
#  24  Floor covering:             538 non-null    object
#  25  Room type:                  695 non-null    object
#  26  Internet:                   839 non-null    object
#  27  Kitchen furniture:          216 non-null    object
#  28  TV:                         155 non-null    object
#  29  Washing machine:            91 non-null     object
#  30  Foundation type:            303 non-null    object
#  31  Overlap type:               351 non-null    object
#  32  Type of the building:       354 non-null    object
#  33  Playground:                 196 non-null    object
#  34  Class:                      80 non-null     object
# dtypes: float64(1), object(34)
# memory usage: 12.6+ MB

# %%
train.head(100)
# Out:
#                                           breadcrumbs  \
# 0                               [Москва, МЦК Лужники]
# 1   [Москва, Новая Москва, п. Сосенское, п. Коммун...
# 2                  [Москва, МЦК Крымская, ул. Поляны]
# 3          [Москва, Беговой, м. Динамо, МЦК Хорошёво]
# 4     [Москва, Филёвский Парк, м. Фили, МЦК Шелепиха]
# ..                                                ...
# 95  [Москва, Останкинский, м. Алексеевская, МЦК Ро...
# 96    [Москва, Филёвский Парк, м. Фили, МЦК Шелепиха]
# 97  [Москва, Хорошёво-Мнёвники, м. Октябрьское пол...
# 98         [Москва, Зябликово, м. Зябликово, МЦК ЗИЛ]
# 99     [Москва, Бибирево, м. Бибирево, МЦК Владыкино]
#
#                                                  date  \
# 0   [23 февраля 2018, 133, (+2 за сегодня), Обновл...
# 1               [сегодня в 04:52, 3, (+3 за сегодня)]
# 2     [5 марта, 6, (+1 за сегодня), Обновлено 15 мая]
# 3   [22 мая 2018, 60, (+2 за сегодня), Обновлено 1...
# 4   [26 декабря 2018, 13, (+1 за сегодня), Обновле...
# ..                                                ...
# 95  [20 апреля, 7, (+3 за сегодня), Обновлено 17 мая]
# 96  [18 января, 17, (+2 за сегодня), Обновлено 14 ...
# 97                       [17 мая, 3, (+2 за сегодня)]
# 98                       [16 мая, 5, (+1 за сегодня)]
# 99  [14 апреля, 14, (+2 за сегодня), Обновлено 17 ...
#
#                                             geo_block owner       price  \
# 0                              [г. Москва, г. Москва]    []  380.610000
# 1   [Новая Москва, п. Сосенское, п. Коммунарка, Юж...    []    8.004631
# 2        [г. Москва, ул Поляны, г. Москва, ул Поляны]    []    6.520000
# 3            [г. Москва, Беговой, г. Москва, Беговой]    []   20.269686
# 4   [г. Москва, Филёвский Парк, г. Москва, Филёвск...    []   15.100880
# ..                                                ...   ...         ...
# 95  [г. Москва, Останкинский, г. Москва, Останкинс...    []   32.146000
# 96  [г. Москва, Филёвский Парк, г. Москва, Филёвск...    []   13.950000
# 97  [г. Москва, Хорошёво-Мнёвники, ул Народного Оп...    []    7.900000
# 98       [г. Москва, Зябликово, г. Москва, Зябликово]    []    6.765000
# 99         [г. Москва, Бибирево, г. Москва, Бибирево]    []    8.300000
#
#                                             Security:    Building type:  \
# 0   secure Parking, video surveillance, 24-hour se...             Brick
# 1                                                 Yes  Monolithic-brick
# 2                                            provided        Monolithic
# 3                                                 NaN        Monolithic
# 4                                                 NaN        Monolithic
# ..                                                ...               ...
# 95                                                NaN        Monolithic
# 96                                                NaN        Monolithic
# 97                                           provided        Monolithic
# 98  fenced area, access control system, video surv...        Monolithic
# 99                                                NaN             Panel
#
#    Object type:            Ad type: Commission agent: Construction phase:  \
# 0    apartments        new building            no fee        Commissioned
# 1          flat  from the developer            no fee      Building walls
# 2    apartments  from the developer            no fee              Finish
# 3          flat        new building            no fee                 NaN
# 4    apartments           secondary            no fee                 NaN
# ..          ...                 ...               ...                 ...
# 95   apartments           secondary            no fee                 NaN
# 96         flat        new building            no fee      Building walls
# 97   apartments        new building            no fee        Commissioned
# 98         flat  from the developer            no fee          Playground
# 99   apartments           secondary            no fee                 NaN
#
#     Housing class: Elevator: Bathroom type: Balcony type: Mortgage possible:  \
# 0      Elite class       NaN            NaN           NaN                NaN
# 1    Comfort class       yes       separate       balcony                yes
# 2    Comfort class       yes       combined           NaN                NaN
# 3              NaN       yes            NaN        loggia                yes
# 4              NaN       NaN            NaN           NaN                NaN
# ..             ...       ...            ...           ...                ...
# 95             NaN       NaN            NaN           NaN                NaN
# 96  Business class       yes            NaN        loggia                yes
# 97  Business class       NaN            NaN           NaN                NaN
# 98   Comfort class       yes            NaN           NaN                yes
# 99             NaN       NaN            NaN           NaN                NaN
#
#    The view from the window: Garbage chute: Repair: Fridge: Phone: Furniture:  \
# 0                        NaN            NaN     NaN     NaN    NaN        NaN
# 1                        NaN            NaN     NaN     NaN    NaN        NaN
# 2                       yard            yes     NaN     NaN    NaN        NaN
# 3                     street            yes     NaN     NaN    NaN        NaN
# 4                        NaN            NaN     NaN     NaN    NaN        NaN
# ..                       ...            ...     ...     ...    ...        ...
# 95                       NaN            NaN     NaN     NaN    NaN        NaN
# 96                    street            yes     NaN     NaN    NaN        NaN
# 97                       NaN            NaN     NaN     NaN    NaN        NaN
# 98                       NaN            yes     NaN     NaN    NaN        NaN
# 99                       NaN            NaN     NaN     NaN    NaN        NaN
#
#    Free layout: It is possible to bargain: Floor covering: Room type:  \
# 0           NaN                        NaN             NaN        NaN
# 1           NaN                        NaN             NaN        NaN
# 2           NaN                        NaN             NaN        NaN
# 3           NaN                        NaN             NaN        NaN
# 4           NaN                        NaN             NaN        NaN
# ..          ...                        ...             ...        ...
# 95          NaN                        NaN             NaN        NaN
# 96          NaN                        NaN             NaN        NaN
# 97          NaN                        NaN             NaN        NaN
# 98          yes                        NaN             NaN        NaN
# 99          NaN                        NaN             NaN        NaN
#
#    Internet: Kitchen furniture:  TV: Washing machine: Foundation type:  \
# 0        NaN                NaN  NaN              NaN              NaN
# 1        NaN                NaN  NaN              NaN              NaN
# 2        NaN                NaN  NaN              NaN              NaN
# 3        NaN                NaN  NaN              NaN              NaN
# 4        NaN                NaN  NaN              NaN              NaN
# ..       ...                ...  ...              ...              ...
# 95       NaN                NaN  NaN              NaN              NaN
# 96       NaN                NaN  NaN              NaN              NaN
# 97       NaN                NaN  NaN              NaN              NaN
# 98       NaN                NaN  NaN              NaN              NaN
# 99       NaN                NaN  NaN              NaN              NaN
#
#    Overlap type: Type of the building: Playground: Class:
# 0            NaN                   NaN         NaN    NaN
# 1            NaN                   NaN         NaN    NaN
# 2            NaN                   NaN         NaN    NaN
# 3            NaN                   NaN         NaN    NaN
# 4            NaN                   NaN         NaN    NaN
# ..           ...                   ...         ...    ...
# 95           NaN                   NaN         NaN    NaN
# 96           NaN                   NaN         NaN    NaN
# 97           NaN                   NaN         NaN    NaN
# 98           NaN                   NaN         NaN    NaN
# 99           NaN                   NaN         NaN    NaN
#
# [100 rows x 35 columns]

# %%
# train and test values comparison
for x in train[train.columns[6:]]:
    print(x, '\n', train[x].unique(), '\n')
    print(x, '\n', test[x].unique(), '\n')
    print('='*60)
# Out:
# Building type:
#  ['Brick' 'Monolithic-brick' 'Monolithic' 'Panel' 'Block' nan 'Wooden'
#  'Panel-brick' 'Cast stone' 'Stalinist']
#
# Building type:
#  ['Monolithic' 'Panel' 'Monolithic-brick' 'Brick' 'Block' nan 'Stalinist'
#  'Cast stone' 'Wooden' 'Panel-brick']
#
# ============================================================
# Object type:
#  ['apartments' 'flat' 'Studio' nan 'penthouse']
#
# Object type:
#  ['flat' 'apartments' 'Studio' 'penthouse' nan]
#
# ============================================================
# Ad type:
#  ['new building' 'from the developer' 'secondary' nan]
#
# Ad type:
#  ['from the developer' 'secondary' 'new building' nan]
#
# ============================================================
# Commission agent:
#  ['no fee' nan]
#
# Commission agent:
#  ['no fee' nan]
#
# ============================================================
# Construction phase:
#  ['Commissioned' 'Building walls' 'Finish' nan 'Playground' 'Pit' 'Project'
#  'Is GK']
#
# Construction phase:
#  ['Finish' nan 'Building walls' 'Commissioned' 'Project' 'Playground' 'Pit'
#  'Is GK']
#
# ============================================================
# Housing class:
#  ['Elite class' 'Comfort class' nan 'Business class' 'Economy class']
#
# Housing class:
#  ['Comfort class' nan 'Business class' 'Economy class' 'Elite class']
#
# ============================================================
# Elevator:
#  [nan 'yes']
#
# Elevator:
#  ['yes' nan]
#
# ============================================================
# Bathroom type:
#  [nan 'separate' 'combined' 'two']
#
# Bathroom type:
#  ['two' nan 'separate' 'combined']
#
# ============================================================
# Balcony type:
#  [nan 'balcony' 'loggia' 'two balcony' 'balcony and loggia' 'two loggia']
#
# Balcony type:
#  ['balcony' nan 'loggia' 'two loggia' 'two balcony' 'balcony and loggia']
#
# ============================================================
# Mortgage possible:
#  [nan 'yes']
#
# Mortgage possible:
#  ['yes' nan]
#
# ============================================================
# The view from the window:
#  [nan 'yard' 'street']
#
# The view from the window:
#  [nan 'street' 'yard']
#
# ============================================================
# Garbage chute:
#  [nan 'yes']
#
# Garbage chute:
#  [nan 'yes']
#
# ============================================================
# Repair:
#  [nan 'euro' 'cosmetic' 'designer' 'no trim' 'no repair' 'finished']
#
# Repair:
#  [nan 'euro' 'designer' 'no repair' 'cosmetic' 'no trim' 'finished']
#
# ============================================================
# Fridge:
#  [nan 'yes']
#
# Fridge:
#  [nan 'yes']
#
# ============================================================
# Phone:
#  [nan 'yes']
#
# Phone:
#  [nan 'yes']
#
# ============================================================
# Furniture:
#  [nan 'yes']
#
# Furniture:
#  [nan 'yes']
#
# ============================================================
# Free layout:
#  [nan 'yes']
#
# Free layout:
#  [nan 'yes']
#
# ============================================================
# It is possible to bargain:
#  [nan 'yes']
#
# It is possible to bargain:
#  [nan 'yes']
#
# ============================================================
# Floor covering:
#  [nan 'laminate' 'parquet' 'linoleum' 'carpet']
#
# Floor covering:
#  [nan 'laminate' 'linoleum' 'parquet' 'carpet']
#
# ============================================================
# Room type:
#  [nan 'separate' 'adjacent' 'adjacent-separate']
#
# Room type:
#  [nan 'separate' 'adjacent-separate' 'adjacent']
#
# ============================================================
# Internet:
#  [nan 'yes']
#
# Internet:
#  [nan 'yes']
#
# ============================================================
# Kitchen furniture:
#  [nan 'yes']
#
# Kitchen furniture:
#  [nan 'yes']
#
# ============================================================
# TV:
#  [nan 'yes']
#
# TV:
#  [nan 'yes']
#
# ============================================================
# Washing machine:
#  [nan 'yes']
#
# Washing machine:
#  [nan 'yes']
#
# ============================================================
# Foundation type:
#  [nan 'Ribbon' 'Pile' 'Solid' 'Concrete pillars' 'Other' 'Precast']
#
# Foundation type:
#  [nan 'Pile' 'Other' 'Ribbon' 'Concrete pillars' 'Solid' 'Precast']
#
# ============================================================
# Overlap type:
#  [nan 'Reinforced Concrete' 'Wooden' 'Mixed' 'Other']
#
# Overlap type:
#  [nan 'Reinforced Concrete' 'Wooden']
#
# ============================================================
# Type of the building:
#  [nan 'Apartment building' 'A residential house of the blocked development']
#
# Type of the building:
#  [nan 'Apartment building' 'A residential house of the blocked development'
#  'Specialized housing stock']
#
# ============================================================
# Playground:
#  [nan 'yes']
#
# Playground:
#  [nan 'yes']
#
# ============================================================
# Class:
#  [nan 'elite real estate']
#
# Class:
#  [nan 'elite real estate']
#
# ============================================================

# %%
# object type
train['Object type:'].unique()
# Out:
# array(['apartments', 'flat', 'Studio', nan, 'penthouse'], dtype=object)

# %%
# building type

train['Building type:'].unique()
# Out:
# array(['Brick', 'Monolithic-brick', 'Monolithic', 'Panel', 'Block', nan,
#        'Wooden', 'Panel-brick', 'Cast stone', 'Stalinist'], dtype=object)

# %%
# factorize building type by price
b_type_labels_by_mean = train[['Building type:', 'price']].groupby('Building type:').agg('mean').reset_index().sort_values('price')['Building type:'].values
b_type_labels_by_median = train[['Building type:', 'price']].groupby('Building type:').agg('median').reset_index().sort_values('price')['Building type:'].values

b_type_values = [x for x in range(1, len(b_type_labels_by_mean)+1)]

lab_rep_dict_mean = dict(zip(b_type_labels_by_mean, b_type_values))
lab_rep_dict_median = dict(zip(b_type_labels_by_median, b_type_values))

train['Building type:'].replace(lab_rep_dict_mean)
# Out:
# 0        7.0
# 1        8.0
# 2        5.0
# 3        5.0
# 4        5.0
#         ...
# 45689    1.0
# 45690    5.0
# 45691    1.0
# 45692    5.0
# 45693    5.0
# Name: Building type:, Length: 45694, dtype: float64

# %%
# building type factorization check
print(lab_rep_dict_mean)
# Out:
# {'Panel': 1, 'Block': 2, 'Panel-brick': 3, 'Cast stone': 4, 'Monolithic': 5, 'Stalinist': 6, 'Brick': 7, 'Monolithic-brick': 8, 'Wooden': 9}

# %%
# security

# train['Security:'].describe()
[str(x) for x in train['Security:'][train['Security:'].notnull()].values]

word_counter = {}
unique_values = []
for word in ' '.join([str(x) for x in train['Security:'][train['Security:'].notnull()].values]).split():
    
    word = word.lower().strip(',')
    
    if word not in word_counter:
        word_counter[word] = 0
        unique_values.append(word)
    word_counter[word.lower()] +=1

list(dict(sorted(word_counter.items(), key=lambda item: item[1], reverse=True)))[:30]
# dict(sorted(word_counter.items(), key=lambda item: item[1], reverse=True))
# Out:
# ['provided',
#  'area',
#  'closed',
#  'video',
#  'surveillance',
#  'concierge',
#  'the',
#  'fenced',
#  'security',
#  'system',
#  'yes',
#  'access',
#  'control',
#  'clock',
#  'round',
#  'and',
#  'guarded',
#  'perimeter',
#  'of',
#  'barrier',
#  'protected',
#  'with',
#  'around',
#  'by',
#  'intercom',
#  'cameras',
#  'well',
#  'landscaping',
#  'use',
#  'small']

# %%
# train['security_wrd_cnt'] = df['Security:'].map(lambda x: len(str(x).split()))
# train['security_len'] = df['Security:'].map(lambda x: len(str(x)))

def get_security_len(field):
    try:
        return len(field.strip())
    
    except:
        return None

def get_security_wrd_cnt(field):
    try:
        return len(field.split())
    
    except:
        return None
    
train['Security:'].map(get_security_len)
# Out:
# 0        78.0
# 1         3.0
# 2         8.0
# 3         NaN
# 4         NaN
#          ...
# 45689     NaN
# 45690     8.0
# 45691     NaN
# 45692     NaN
# 45693    22.0
# Name: Security:, Length: 45694, dtype: float64

# %%
# owner

def get_owner(field):
    if len(field) > 0:
        return str(field[0]).strip().lower()
    else:
        return None
    
def get_owner_len(field):
    try:
        return len(field)
    except:
        return None  
    
def get_owner_cnt(field):
    try:
        return len(field.split())
    except:
        return None  

train['owner'].map(get_owner).value_counts().head(40)
# train['owner'].head()
# Out:
# жк "крылья". доп. скидка 5%!      499
# квартиры в жк "аквилон park"!     299
# район «скандинавия»               289
# переделкино ближнее               271
# район «испанские кварталы»        206
# жк мир митино: тройные скидки     203
# жк "румянцево-парк"               200
# жк триколор на вднх.              195
# квартиры в жк сиреневый парк      137
# жк «остафьево»                    136
# жк "семеновский парк"             133
# жк "life-ботанический сад"        127
# город-парк «первый московский»    118
# жилой комплекс «летний сад»       117
# уникальный жк «onyx deluxe»       110
# городской квартал big time.       104
# квартиры в жк "лучи"               97
# жк «розмарин» - дом построен!      92
# клубный дом soho+noho              86
# жк «нормандия»                     76
# жк "москвичка"                     73
# жк «царская площадь».              72
# квартиры в жк "фонвизинский"       70
# жк"геометрия". скоро заселение     65
# жилой квартал lucky                59
# topbn.marketing@gmail.com          46
# жк кленовые аллеи                  45
# жк ilove м.алексеевская            33
# жилой район «москва а101»          33
# анастасия                          32
# sfn-9151912909@yandex.ru           29
# счастье в кусково                  27
# олеся прохорова                    23
# светлана                           22
# счастье на соколе                  16
# инвест недвижимость                15
# жк фили сити                       14
# счастье на пресне                  13
# андрей                             13
# нефедов геннадий геннадиевич       12
# Name: owner, dtype: int64

# %%
# try and print factorization by mean price for clumns 6:...
for col in train.columns[6:]:
    a = [str(x) for x in train[[col, 'price']].fillna(-1).groupby(col).agg('mean').reset_index().sort_values('price')[col].values]
    type_values = [int(x) for x in range(1, len(a)+1)]
    lab_rep_dict_mean = dict(zip(a, type_values))
    print(a)
    print(lab_rep_dict_mean, '\n')
# Out:
# ['Panel', 'Block', 'Panel-brick', 'Cast stone', 'Monolithic', 'Stalinist', '-1', 'Brick', 'Monolithic-brick', 'Wooden']
# {'Panel': 1, 'Block': 2, 'Panel-brick': 3, 'Cast stone': 4, 'Monolithic': 5, 'Stalinist': 6, '-1': 7, 'Brick': 8, 'Monolithic-brick': 9, 'Wooden': 10}
#
# ['Studio', '-1', 'flat', 'apartments', 'penthouse']
# {'Studio': 1, '-1': 2, 'flat': 3, 'apartments': 4, 'penthouse': 5}
#
# ['-1', 'from the developer', 'secondary', 'new building']
# {'-1': 1, 'from the developer': 2, 'secondary': 3, 'new building': 4}
#
# ['-1', 'no fee']
# {'-1': 1, 'no fee': 2}
#
# ['Pit', 'Playground', 'Building walls', 'Finish', '-1', 'Is GK', 'Project', 'Commissioned']
# {'Pit': 1, 'Playground': 2, 'Building walls': 3, 'Finish': 4, '-1': 5, 'Is GK': 6, 'Project': 7, 'Commissioned': 8}
#
# ['Comfort class', 'Economy class', '-1', 'Business class', 'Elite class']
# {'Comfort class': 1, 'Economy class': 2, '-1': 3, 'Business class': 4, 'Elite class': 5}
#
# ['yes', '-1']
# {'yes': 1, '-1': 2}
#
# ['combined', 'separate', '-1', 'two']
# {'combined': 1, 'separate': 2, '-1': 3, 'two': 4}
#
# ['loggia', 'balcony', '-1', 'balcony and loggia', 'two loggia', 'two balcony']
# {'loggia': 1, 'balcony': 2, '-1': 3, 'balcony and loggia': 4, 'two loggia': 5, 'two balcony': 6}
#
# ['yes', '-1']
# {'yes': 1, '-1': 2}
#
# ['yard', 'street', '-1']
# {'yard': 1, 'street': 2, '-1': 3}
#
# ['yes', '-1']
# {'yes': 1, '-1': 2}
#
# ['euro', 'cosmetic', 'finished', 'no trim', 'no repair', '-1', 'designer']
# {'euro': 1, 'cosmetic': 2, 'finished': 3, 'no trim': 4, 'no repair': 5, '-1': 6, 'designer': 7}
#
# ['-1', 'yes']
# {'-1': 1, 'yes': 2}
#
# ['-1', 'yes']
# {'-1': 1, 'yes': 2}
#
# ['-1', 'yes']
# {'-1': 1, 'yes': 2}
#
# ['-1', 'yes']
# {'-1': 1, 'yes': 2}
#
# ['yes', '-1']
# {'yes': 1, '-1': 2}
#
# ['carpet', 'linoleum', 'laminate', '-1', 'parquet']
# {'carpet': 1, 'linoleum': 2, 'laminate': 3, '-1': 4, 'parquet': 5}
#
# ['adjacent-separate', '-1', 'separate', 'adjacent']
# {'adjacent-separate': 1, '-1': 2, 'separate': 3, 'adjacent': 4}
#
# ['-1', 'yes']
# {'-1': 1, 'yes': 2}
#
# ['-1', 'yes']
# {'-1': 1, 'yes': 2}
#
# ['-1', 'yes']
# {'-1': 1, 'yes': 2}
#
# ['-1', 'yes']
# {'-1': 1, 'yes': 2}
#
# ['Ribbon', 'Precast', '-1', 'Other', 'Solid', 'Pile', 'Concrete pillars']
# {'Ribbon': 1, 'Precast': 2, '-1': 3, 'Other': 4, 'Solid': 5, 'Pile': 6, 'Concrete pillars': 7}
#
# ['-1', 'Wooden', 'Mixed', 'Reinforced Concrete', 'Other']
# {'-1': 1, 'Wooden': 2, 'Mixed': 3, 'Reinforced Concrete': 4, 'Other': 5}
#
# ['-1', 'Apartment building', 'A residential house of the blocked development']
# {'-1': 1, 'Apartment building': 2, 'A residential house of the blocked development': 3}
#
# ['-1', 'yes']
# {'-1': 1, 'yes': 2}
#
# ['-1', 'elite real estate']
# {'-1': 1, 'elite real estate': 2}

# %%
# check mean price for columns 6:... ( with fillna -1)
for col in train[train.columns[6:]]:
    if len(train[col].unique()) <=2:
#         print(col, '\n', train[col].unique(), train[col].count())
        print(train[[col, 'price']].fillna(-1).groupby(col).agg('mean').plot(kind='bar'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
train.columns
# Out:
# Index(['breadcrumbs', 'date', 'geo_block', 'owner', 'price', 'Security:',
#        'Building type:', 'Object type:', 'Ad type:', 'Commission agent:',
#        'Construction phase:', 'Housing class:', 'Elevator:', 'Bathroom type:',
#        'Balcony type:', 'Mortgage possible:', 'The view from the window:',
#        'Garbage chute:', 'Repair:', 'Fridge:', 'Phone:', 'Furniture:',
#        'Free layout:', 'It is possible to bargain:', 'Floor covering:',
#        'Room type:', 'Internet:', 'Kitchen furniture:', 'TV:',
#        'Washing machine:', 'Foundation type:', 'Overlap type:',
#        'Type of the building:', 'Playground:', 'Class:'],
#       dtype='object')

# %% [markdown]
# ### breadcrumps

# %%
# count words
word_counter = {}
unique_values = []
for lista in train['breadcrumbs'].values:
    for word in lista:
        if word.lower() not in word_counter:
            word_counter[word.lower()] = 0
            unique_values.append(word.lower())
        word_counter[word.lower()] +=1

list(dict(sorted(word_counter.items(), key=lambda item: item[1], reverse=True)))[:50]
dict(sorted(word_counter.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'москва': 45694,
#  'мцк крымская': 7469,
#  'новая москва': 6140,
#  'мцк кутузовская': 3852,
#  'п. сосенское': 3398,
#  'мцк шелепиха': 3279,
#  'мцк лужники': 3155,
#  'мцк коптево': 2327,
#  'п. коммунарка': 2314,
#  'мцк хорошёво': 2129,
#  'южное бутово': 2076,
#  'мцк зил': 1954,
#  'мцк шоссе энтузиастов': 1803,
#  'м. бунинская аллея': 1751,
#  'мцк нижегородская': 1731,
#  'мцк угрешская': 1643,
#  'мцк владыкино': 1568,
#  'хорошёво-мнёвники': 1560,
#  'мцк ботанический сад': 1507,
#  'мцк лихоборы': 1488,
#  'ул. дыбенко': 1395,
#  'мцк балтийская': 1362,
#  'ул. лобачевского': 1344,
#  'мцк зорге': 1269,
#  'п. московский': 1240,
#  'м. выхино': 1207,
#  'филёвский парк': 1197,
#  'м. октябрьское поле': 1152,
#  'мцк ростокино': 1146,
#  'тропарёво-никулино': 1115,
#  'ховрино': 1101,
#  'м. ховрино': 1098,
#  'раменки': 1096,
#  'м. саларьево': 1010,
#  'м. пятницкое шоссе': 931,
#  'люблино': 909,
#  'ул. верхние поля': 905,
#  'м. братиславская': 898,
#  'некрасовка': 874,
#  'м. рязанский проспект': 847,
#  'м. ботанический сад': 827,
#  'м. теплый стан': 815,
#  'тёплый стан': 794,
#  'кунцево': 776,
#  'мцк деловой центр': 758,
#  'м. домодедовская': 743,
#  'орехово-борисово южное': 740,
#  'м. раменки': 735,
#  'мцк локомотив': 734,
#  'м. фили': 729,
#  'г. московский': 719,
#  'выхино-жулебино': 695,
#  'мцк андроновка': 690,
#  'д. николо-хованское': 679,
#  'м. молодежная': 655,
#  'зябликово': 625,
#  'мцк новохохловская': 606,
#  'мцк соколиная гора': 596,
#  'рязанский': 590,
#  'мцк стрешнево': 584,
#  'м. зябликово': 584,
#  'п. внуковское': 566,
#  'марьино': 564,
#  'м. люблино': 539,
#  'лефортово': 532,
#  'мцк площадь гагарина': 522,
#  'мцк окружная': 509,
#  'м. селигерская': 506,
#  'пресненский': 500,
#  'пр-кт. мира': 496,
#  'мцк панфиловская': 477,
#  'мцк верхние котлы': 468,
#  'ул. зорге': 464,
#  'ул. поляны': 446,
#  'м. мичуринский проспект': 429,
#  'отрадное': 417,
#  'г. зеленоград': 389,
#  'свиблово': 378,
#  'м. динамо': 375,
#  'м. шелепиха': 363,
#  'дмитровский': 361,
#  'м. улица скобелевская': 346,
#  'тимирязевский': 346,
#  'м. дмитровская': 346,
#  'бутырский': 313,
#  'м. авиамоторная': 310,
#  'останкинский': 295,
#  'ул. берзарина': 289,
#  'м. говорово': 281,
#  'п. филимонковское': 281,
#  'м. бабушкинская': 280,
#  'мцк бульвар рокоссовского': 279,
#  'мцк дубровка': 275,
#  'ростокино': 273,
#  'солнцево': 268,
#  'черёмушки': 268,
#  'беговой': 267,
#  'головинский': 266,
#  'марьина роща': 255,
#  'м. площадь ильича': 252,
#  'западное дегунино': 251,
#  'м. водный стадион': 250,
#  'щукино': 242,
#  'м. солнцево': 240,
#  'митино': 235,
#  'м. верхние лихоборы': 225,
#  'ул. римского-корсакова': 221,
#  'м. владыкино': 220,
#  'ул. золоторожский вал': 215,
#  'м. савеловская': 214,
#  'ул. академика павлова': 214,
#  'ул. генерала белова': 213,
#  'м. профсоюзная': 213,
#  'хамовники': 208,
#  'южное медведково': 206,
#  'измайлово': 206,
#  'д. румянцево': 203,
#  'м. крылатское': 201,
#  'м. улица 1905 года': 199,
#  'крылатское': 199,
#  'м. отрадное': 197,
#  'красносельский': 197,
#  'даниловский': 196,
#  'ул. красная сосна': 196,
#  'п. свиблово': 193,
#  'ярославский': 188,
#  'крюково': 184,
#  'ул. сергея макеева': 180,
#  'м. медведково': 178,
#  'п. некрасовка': 177,
#  'пр-кт. академика сахарова': 177,
#  'м. красные ворота': 177,
#  'м. международная': 174,
#  'д. староселье': 171,
#  'северный': 169,
#  'м. алексеевская': 163,
#  'п. десеновское': 158,
#  'п. рязановское': 155,
#  'с. остафьево': 152,
#  'м. измайловская': 150,
#  'ул. ляпидевского': 146,
#  'м. белорусская': 145,
#  'басманный': 142,
#  'м. рассказовка': 141,
#  'м. речной вокзал': 141,
#  'ново-переделкино': 138,
#  'ул. расплетина': 138,
#  'проезд. серебрякова': 138,
#  'мцк автозаводская': 136,
#  'левобережный': 134,
#  'тверской': 133,
#  'ул. народного ополчения': 127,
#  'текстильщики': 127,
#  'м. фрунзенская': 127,
#  'м. минская': 124,
#  'п. марушкинское': 123,
#  'хорошёвский': 119,
#  'алексеевский': 116,
#  'таганский': 112,
#  'м. кунцевская': 111,
#  'м. лермонтовский проспект': 107,
#  'северное медведково': 105,
#  'ул. ефремова': 102,
#  'м. автозаводская': 101,
#  'дорогомилово': 101,
#  'чертаново южное': 99,
#  'м. текстильщики': 96,
#  'ул. вавилова': 94,
#  'мцк белокаменная': 90,
#  'м. полежаевская': 88,
#  'м. юго-западная': 87,
#  'чертаново центральное': 86,
#  'лосиноостровский': 85,
#  'д. столбово': 85,
#  'м. фонвизинская': 81,
#  'аэропорт': 81,
#  'м. тимирязевская': 79,
#  'замоскворечье': 79,
#  'северное бутово': 76,
#  'новогиреево': 75,
#  'м. тульская': 74,
#  'ул. петра алексеева': 73,
#  'бабушкинский': 71,
#  'нижегородский': 71,
#  'м. алтуфьево': 69,
#  'м. новокосино': 68,
#  'д. саларьево': 68,
#  'ш. дмитровское': 67,
#  'ул. новый арбат': 67,
#  'лианозово': 66,
#  'нагорный': 65,
#  'пр-кт. маршала жукова': 63,
#  'якиманка': 63,
#  'м. новые черемушки': 63,
#  'м. щелковская': 63,
#  'м. университет': 63,
#  'богородское': 62,
#  'м. бульвар рокоссовского': 62,
#  'мцк измайлово': 62,
#  'ул. бочкова': 61,
#  'м. чкаловская': 61,
#  'вешняки': 59,
#  'м. щукинская': 59,
#  'соколиная гора': 59,
#  'северное тушино': 57,
#  'м. марьина роща': 57,
#  'п. первомайское': 56,
#  'м. лесопарковая': 56,
#  'м. вднх': 56,
#  'п. воскресенское': 55,
#  'м. ломоносовский проспект': 53,
#  'б-р. генерала карбышева': 52,
#  'м. семеновская': 52,
#  'савёловский': 51,
#  'м. царицыно': 50,
#  'ул. земляной вал': 49,
#  'м. выставочная': 49,
#  'м. спортивная': 49,
#  'царицыно': 48,
#  'ул. михайлова': 47,
#  'м. серпуховская': 46,
#  'м. академическая': 46,
#  'коньково': 45,
#  'арбат': 44,
#  'м. аннино': 44,
#  'м. новогиреево': 44,
#  'академический': 44,
#  'м. улица академика янгеля': 42,
#  'пер. хилков': 41,
#  'ул. нежинская': 40,
#  'восточное измайлово': 40,
#  'м. первомайская': 40,
#  'ул. генерала глаголева': 39,
#  'пер. холодильный': 39,
#  'м. печатники': 39,
#  'м. марьино': 39,
#  'м. петровский парк': 39,
#  'ул. паршина': 38,
#  'м. смоленская': 37,
#  'м. сходненская': 37,
#  'ул. фадеева': 37,
#  'ул. юннатов': 37,
#  'м. бауманская': 37,
#  'ул. орджоникидзе': 36,
#  'м. проспект вернадского': 36,
#  'проспект вернадского': 35,
#  'м. таганская': 35,
#  'мещанский': 34,
#  'м. петровско-разумовская': 34,
#  'м. красногвардейская': 34,
#  'м. аэропорт': 34,
#  'м. киевская': 34,
#  'д. язово': 32,
#  'м. кузьминки': 32,
#  'м. планерная': 32,
#  'м. тропарево': 32,
#  'д. говорово': 31,
#  'ул. маршала катукова': 31,
#  'ул. циолковского': 31,
#  'ул. арбат': 31,
#  'пер. богословский': 31,
#  'кузьминки': 31,
#  'м. бульвар дмитрия донского': 30,
#  'м. бибирево': 30,
#  'м. сокол': 30,
#  'м. пражская': 30,
#  'м. строгино': 30,
#  'бибирево': 29,
#  'строгино': 29,
#  'м. коломенская': 29,
#  'м. славянский бульвар': 29,
#  'м. маяковская': 29,
#  'перово': 29,
#  'сокол': 28,
#  'покровское-стрешнево': 28,
#  'м. беляево': 28,
#  'пер. коробейников': 28,
#  'ясенево': 27,
#  'м. ясенево': 27,
#  'пл. курского вокзала': 27,
#  'нагатинский затон': 27,
#  'ул. адмирала макарова': 27,
#  'орехово-борисово северное': 27,
#  'п. щаповское': 27,
#  'ул. речников': 26,
#  'м. орехово': 26,
#  'м. шаболовская': 26,
#  'м. парк культуры': 26,
#  'м. ленинский проспект': 26,
#  'м. новопеределкино': 25,
#  'пер. басманный': 25,
#  'г. щербинка': 25,
#  'м. войковская': 25,
#  'м. курская': 25,
#  'м. цветной бульвар': 24,
#  'м. беломорская': 24,
#  'м. тушинская': 24,
#  'г. троицк': 24,
#  'ул. фабрициуса': 24,
#  'м. озёрная': 24,
#  'м. жулебино': 23,
#  'м. менделеевская': 23,
#  'м. чертановская': 23,
#  'м. деловой центр': 22,
#  'м. алма-атинская': 22,
#  'м. шипиловская': 22,
#  'москворечье-сабурово': 22,
#  'ул. мельникова': 22,
#  'м. беговая': 22,
#  'войковский': 22,
#  'м. нахимовский проспект': 22,
#  'д. ямонтово': 21,
#  'м. перово': 21,
#  'м. калужская': 20,
#  'м. парк победы': 20,
#  'ул. усиевича': 20,
#  'южнопортовый': 20,
#  'м. преображенская площадь': 20,
#  'пр-кт. 40 лет октября': 20,
#  'ул. серпуховский вал': 20,
#  'м. митино': 20,
#  'ул. демьяна бедного': 19,
#  'гагаринский': 19,
#  'пр-кт. вернадского': 19,
#  'ул. палиха': 19,
#  'м. свиблово': 18,
#  'м. кантемировская': 18,
#  'п. дорожно-ремонтного пункта 3': 18,
#  'м. павелецкая': 18,
#  'фили-давыдково': 18,
#  'м. шоссе энтузиастов': 18,
#  'м. полянка': 17,
#  'м. варшавская': 17,
#  'нагатино-садовники': 17,
#  'м. новокузнецкая': 17,
#  'ул. черняховского': 17,
#  'м. пролетарская': 16,
#  'пер. гороховский': 16,
#  'пер. тессинский': 16,
#  'м. октябрьская': 16,
#  'ул. пресненский вал': 15,
#  'сокольники': 15,
#  'м. сокольники': 15,
#  'м. электрозаводская': 15,
#  'м. кутузовская': 15,
#  'наб. павелецкая': 15,
#  'ул. 40 лет октября': 15,
#  'пер. еропкинский': 15,
#  'м. улица старокачаловская': 15,
#  'ул. софьи ковалевской': 15,
#  'м. нагатинская': 15,
#  'м. нагорная': 15,
#  'м. волоколамская': 15,
#  'м. южная': 15,
#  'можайский': 15,
#  'ул. коминтерна': 15,
#  'ул. новая дорога': 14,
#  'м. борисово': 14,
#  'пер. докучаев': 14,
#  'м. цска': 14,
#  'донской': 14,
#  'чертаново северное': 14,
#  'п. новофедоровское': 14,
#  'м. арбатская': 14,
#  'ул. комдива орлова': 14,
#  'м. римская': 13,
#  'м. сухаревская': 13,
#  'ул. багрицкого': 13,
#  'м. тверская': 13,
#  'пер. даев': 13,
#  'м. чистые пруды': 13,
#  'м. филевский парк': 13,
#  'м. багратионовская': 12,
#  'м. дубровка': 12,
#  'преображенское': 12,
#  'м. третьяковская': 12,
#  'м. охотный ряд': 12,
#  'м. коньково': 12,
#  'ул. василисы кожиной': 12,
#  'ул. викторенко': 11,
#  'м. каховская': 11,
#  'м. волгоградский проспект': 11,
#  'пер. подсосенский': 11,
#  'м. севастопольская': 11,
#  'ул. маресьева': 11,
#  'м. баррикадная': 11,
#  'ул. мусы джалиля': 11,
#  'ул. покрышкина': 11,
#  'ул. академика анохина': 11,
#  'ул. скульптора мухиной': 10,
#  'б-р. яна райниса': 10,
#  'ул. островитянова': 10,
#  'м. бульвар адмирала ушакова': 10,
#  'м. добрынинская': 10,
#  'м. марксистская': 10,
#  'ул. каховка': 10,
#  'го троицк': 10,
#  'м. крестьянская застава': 10,
#  'п. кокошкино': 10,
#  'м. красносельская': 10,
#  'п. киевский': 9,
#  'ул. авиаконструктора микояна': 9,
#  'пер. курсовой': 9,
#  'м. технопарк': 9,
#  'ул. авиаторов': 9,
#  'м. студенческая': 9,
#  'д. пыхтино': 9,
#  'м. новоясеневская': 9,
#  'п. вороновское': 9,
#  'пер. петра алексеева 1-й': 9,
#  'южное тушино': 9,
#  'м. проспект мира': 9,
#  'пер. электрический': 9,
#  'м. рижская': 9,
#  'рп. киевский': 8,
#  'м. краснопресненская': 8,
#  'ул. радужная': 8,
#  'м. румянцево': 8,
#  'ул. зацепа': 8,
#  'п. краснопахорское': 8,
#  'м. пионерская': 8,
#  'м. пушкинская': 8,
#  'м. кожуховская': 8,
#  'очаково-матвеевское': 7,
#  'м. новослободская': 7,
#  'ул. автозаводская': 7,
#  'проезд. шокальского': 7,
#  'д. большое свинорье': 7,
#  'м. улица горчакова': 7,
#  'ул. недорубова': 7,
#  'ул. гарибальди': 7,
#  'ломоносовский': 7,
#  'м. черкизовская': 7,
#  'пер. хлебный': 7,
#  'зюзино': 7,
#  'м. достоевская': 7,
#  'п. щапово': 7,
#  'ул. старокрымская': 7,
#  'б-р. дмитрия донского': 7,
#  'м. котельники': 6,
#  'ул. фрунзенская 2-я': 6,
#  'сп сосенское': 6,
#  'ул. космонавтов': 6,
#  'ул. адмирала лазарева': 6,
#  'м. волжская': 6,
#  'пр-кт. ленинский': 6,
#  'м. кропоткинская': 6,
#  'д. марушкино': 6,
#  'ул. наметкина': 6,
#  'ул. покровка': 6,
#  'ул. симоновский вал': 6,
#  'ул. крылатские холмы': 6,
#  'ул. борисовские пруды': 6,
#  'обручевский': 6,
#  'ул. маршала бирюзова': 6,
#  'ул. академика пилюгина': 6,
#  'сп московский': 6,
#  'ул. полбина': 5,
#  'м. сретенский бульвар': 5,
#  'д. марьино': 5,
#  'ул. хромова': 5,
#  'ул. исаковского': 5,
#  'пер. всеволожский': 5,
#  'ул. зои и александра космодемьянских': 5,
#  'ул. 50 лет октября': 5,
#  'м. комсомольская': 5,
#  'ул. плещеева': 5,
#  'проезд. красногвардейский 1-й': 5,
#  'м. окружная': 5,
#  'ул. шолохова': 5,
#  'наб. пресненская': 5,
#  'м. спартак': 5,
#  'п. роговское': 5,
#  'м. чеховская': 5,
#  'ул. столетова': 5,
#  'ул. маршала савицкого': 5,
#  'печатники': 5,
#  'ул. соловьиная роща': 5,
#  'ул. удальцова': 5,
#  'м. каширская': 5,
#  'гольяново': 5,
#  'пр-кт. центральный': 5,
#  'пер. солдатский': 5,
#  'м. трубная': 5,
#  'ул. трофимова': 5,
#  'ул. генерала кузнецова': 5,
#  'ул. маршала тухачевского': 4,
#  'ул. рокотова': 4,
#  'ул. вилиса лациса': 4,
#  'ул. космонавта волкова': 4,
#  'проезд. загорского': 4,
#  'ул. гурьянова': 4,
#  'сп щаповское': 4,
#  'ул. маршала рыбалко': 4,
#  'ул. перерва': 4,
#  'ул. милашенкова': 4,
#  'ул. обручева': 4,
#  'м. бутырская': 4,
#  'ул. крупской': 4,
#  'м. боровское шоссе': 4,
#  'с. вороново': 4,
#  'ул. миклухо-маклая': 4,
#  'п. новобратцевский': 4,
#  'ул. профсоюзная': 4,
#  'ул. маршала федоренко': 4,
#  'ул. 800-летия москвы': 4,
#  'пер. кривоколенный': 4,
#  'ул. юных ленинцев': 4,
#  'ул. полины осипенко': 4,
#  'сп вороновское': 4,
#  'ш. энтузиастов': 4,
#  'ул. новочеремушкинская': 4,
#  'ул. дмитрия ульянова': 4,
#  'ул. маршала захарова': 4,
#  'ул. новаторов': 4,
#  'ул. свободы': 4,
#  'ул. корнейчука': 4,
#  'ул. талалихина': 4,
#  'ул. госпитальный вал': 4,
#  'б-р. маршала рокоссовского': 4,
#  'сп краснопахорское': 4,
#  'ул. дмитриевского': 4,
#  'ул. довженко': 4,
#  'косино-ухтомский': 4,
#  'ул. бестужевых': 4,
#  'пер. звонарский': 4,
#  'ул. твардовского': 4,
#  'ул. красноказарменная': 4,
#  'ул. героев панфиловцев': 4,
#  'пер. стрельбищенский': 3,
#  'ул. бутлерова': 3,
#  'п. птичное': 3,
#  'ул. грина': 3,
#  'ш. каширское': 3,
#  'ул. трубецкая': 3,
#  'ул. академика янгеля': 3,
#  'ул. строителей': 3,
#  'ул. сущевский вал': 3,
#  'коптево': 3,
#  'сп внуковское': 3,
#  'куркино': 3,
#  'ул. раменки': 3,
#  'ул. остоженка': 3,
#  'пр-кт. новоясеневский': 3,
#  'ул. введенского': 3,
#  'п. рогово': 3,
#  'ул. генерала тюленева': 3,
#  'ул. артамонова': 3,
#  'ул. кировоградская': 3,
#  'наб. пречистенская': 3,
#  'ул. плющева': 3,
#  'пер. уваровский': 3,
#  'ул. рождественская': 3,
#  'ул. староволынская': 3,
#  'ул. маршала баграмяна': 3,
#  'с. былово': 3,
#  'ул. дружбы': 3,
#  'ул. бунинская аллея': 3,
#  'ул. льва толстого': 3,
#  'ул. тверская': 3,
#  'ул. мосфильмовская': 3,
#  'пр-кт. панфиловский': 3,
#  'ул. искры': 3,
#  'ул. ивана бабушкина': 3,
#  'метрогородок': 3,
#  'новокосино': 3,
#  'ул. суздальская': 3,
#  'ул. азовская': 3,
#  'ул. барышиха': 3,
#  'ул. бехтерева': 3,
#  'д. зверево': 3,
#  'ул. погодинская': 3,
#  'пер. чапаевский': 3,
#  'м. мякинино': 3,
#  'п. знамя октября': 3,
#  'ул. архитектора власова': 3,
#  'ул. новослободская': 3,
#  'пр-кт. кутузовский': 3,
#  'ул. туристская': 3,
#  'ул. хамовнический вал': 3,
#  'ул. пырьева': 3,
#  'ул. 26-ти бакинских комиссаров': 3,
#  'сп первомайское': 3,
#  'сп десёновское': 3,
#  'ул. люблинская': 3,
#  'ул. текстильщиков': 3,
#  'ул. мытная': 3,
#  'ул. олеко дундича': 3,
#  'м. китай-город': 3,
#  'ул. дубравная': 3,
#  'ш. пятницкое': 3,
#  'ул. ирины левченко': 3,
#  'пр-кт. мичуринский': 3,
#  'ул. кубинка': 3,
#  'ул. хлобыстова': 2,
#  'ул. центральная': 2,
#  'м. лубянка': 2,
#  'пер. печатников': 2,
#  'сп воскресенское': 2,
#  'бирюлёво западное': 2,
#  'ул. каменка': 2,
#  'ул. сталеваров': 2,
#  'ул. авиаконструктора миля': 2,
#  'пр-кт. защитников москвы': 2,
#  'пл. юности': 2,
#  'ул. подольских курсантов': 2,
#  'ул. чертановская': 2,
#  'ул. вешних вод': 2,
#  'ул. нагорная': 2,
#  'пер. ангелов': 2,
#  'ул. спортивная': 2,
#  'ул. цюрупы': 2,
#  'ул. южнобутовская': 2,
#  'ул. покровская': 2,
#  'ул. молдагуловой': 2,
#  'ул. щорса': 2,
#  'пр-кт. октябрьский': 2,
#  'ул. грекова': 2,
#  'ул. липчанского': 2,
#  'ш. варшавское': 2,
#  'ул. красного маяка': 2,
#  'ул. лавочкина': 2,
#  'ул. херсонская': 2,
#  'ул. матросская тишина': 2,
#  'ул. айвазовского': 2,
#  'ул. 1812 года': 2,
#  'ул. академика миллионщикова': 2,
#  'ул. кухмистерова': 2,
#  'ул. егора абакумова': 2,
#  'ул. школьная': 2,
#  'ул. лазурная': 2,
#  'аллея. жемчуговой': 2,
#  'ул. крылатская': 2,
#  'пр-кт. рязанский': 2,
#  'савёлки': 2,
#  'ул. николая химушина': 2,
#  'ул. шоссейная': 2,
#  'ул. саморы машела': 2,
#  'ул. наташи ковшовой': 2,
#  'пер. мерзляковский': 2,
#  'ул. алабяна': 2,
#  'ул. молодцова': 2,
#  'проезд. береговой': 2,
#  'ул. клязьминская': 2,
#  'б-р. жулебинский': 2,
#  'ул. плющиха': 2,
#  'п. лмс': 2,
#  'мкр. центральный': 2,
#  'ул. академика волгина': 2,
#  'ул. красный казанец': 2,
#  'пер. волков': 2,
#  'б-р. ходынский': 2,
#  'ул. пречистенка': 2,
#  'ул. кадырова': 2,
#  'ул. москвитина': 2,
#  'ул. россошанская': 2,
#  'пр-кт. 60-летия октября': 2,
#  'д. горчаково': 2,
#  'ул. андреевка': 2,
#  'пер. ружейный': 2,
#  'ул. василия петушкова': 2,
#  'ул. наримановская': 2,
#  'сп новофёдоровское': 2,
#  'ул. челюскинская': 2,
#  'ул. васильцовский стан': 2,
#  'братеево': 2,
#  'пер. протопоповский': 2,
#  'проезд. кирова': 2,
#  'ш. ленинградское': 2,
#  'ш. ярославское': 2,
#  'бирюлёво восточное': 2,
#  'ул. академика варги': 2,
#  'ул. перовская': 2,
#  'ул. вострухина': 2,
#  'ул. рабочая': 2,
#  'ул. юности': 2,
#  'ул. пришвина': 2,
#  'ул. герасима курина': 2,
#  'д. сосенки': 2,
#  'ул. щукинская': 2,
#  'ул. петра романова': 2,
#  'м. тургеневская': 2,
#  'ул. марьинский парк': 2,
#  'ул. артюхиной': 2,
#  'проезд. лазоревый': 2,
#  'б-р. бескудниковский': 2,
#  'ш. можайское': 2,
#  'ул. бориса галушкина': 2,
#  'ул. яблочкова': 2,
#  'ул. белореченская': 2,
#  'пер. кропоткинский': 2,
#  'восточный': 2,
#  'пр-кт. ленинградский': 2,
#  'ул. правды': 2,
#  'ул. нагатинская': 2,
#  'ул. генерала белобородова': 2,
#  'ул. малыгина': 2,
#  'пл. победы': 2,
#  'п. газопровод': 2,
#  'ул. кржижановского': 2,
#  'ул. винокурова': 2,
#  'пер. брюсов': 2,
#  'ул. николая злобина': 2,
#  'пер. аптекарский': 2,
#  'ул. ухтомского ополчения': 2,
#  'м. театральная': 2,
#  'сп рязановское': 2,
#  'ул. академика виноградова': 2,
#  'мкр. в': 2,
#  'пр-кт. георгиевский': 2,
#  'ул. бачуринская': 2,
#  'ул. клары цеткин': 2,
#  'ул. пестеля': 1,
#  'пер. милютинский': 1,
#  'аллея. яблоневая': 1,
#  'ул. озерная': 1,
#  'проезд. старокрюковский': 1,
#  'пер. столярный': 1,
#  'ул. стромынка': 1,
#  'ул. гоголя': 1,
#  'ул. новокузнецкая': 1,
#  'проезд. востряковский': 1,
#  'ул. добролюбова': 1,
#  'ул. сосенский стан': 1,
#  'ул. набережная': 1,
#  'ул. лескова': 1,
#  'ул. мелитопольская 1-я': 1,
#  'ул. брянская': 1,
#  'пер. старокирочный': 1,
#  'ул. новокузьминская 1-я': 1,
#  'ул. новоалексеевская': 1,
#  'пер. бутиковский': 1,
#  'ул. москворечье': 1,
#  'ул. доброслободская': 1,
#  'ул. подвойского': 1,
#  'проезд. харьковский': 1,
#  'ул. академика комарова': 1,
#  'наб. тараса шевченко': 1,
#  'ул. родионовская': 1,
#  'ул. сайкина': 1,
#  'ул. бианки': 1,
#  'ул. базовская': 1,
#  'котловка': 1,
#  'ул. проходчиков': 1,
#  'ул. гончарова': 1,
#  'ул. ходынская': 1,
#  'пер. воротниковский': 1,
#  'ул. заречная': 1,
#  'ул. полковника милиции курочкина': 1,
#  'ул. летчика грицевца (п внуковское)': 1,
#  'ул. широкая': 1,
#  'ул. петровка': 1,
#  'аллея. сосновая': 1,
#  'пр-кт. андропова': 1,
#  'ул. окская': 1,
#  'ул. красных зорь': 1,
#  'ул. люсиновская': 1,
#  'пер. ботанический': 1,
#  'п. алабушево': 1,
#  'ул. дубнинская': 1,
#  'ул. мостотреста': 1,
#  'ул. ордынка м.': 1,
#  'ул. матвеевская': 1,
#  'проезд. пинский': 1,
#  'ул. онежская': 1,
#  'ул. авиамоторная': 1,
#  'ул. краснодонская': 1,
#  'пер. калашный': 1,
#  'ул. снежная': 1,
#  'проезд. березовой рощи': 1,
#  'ул. 1-я изумрудная': 1,
#  'ул. смирновская': 1,
#  'пр-кт. волгоградский': 1,
#  'пер. трубниковский': 1,
#  'ш. головинское': 1,
#  'ул. воронцовские пруды': 1,
#  'ул. гвардейская': 1,
#  'наб. дербеневская': 1,
#  'ул. рогова': 1,
#  'ул. буракова': 1,
#  'проезд. ферганский': 1,
#  'пл. тверская': 1,
#  'ул. новокрюковская': 1,
#  'ул. кутузова': 1,
#  'ул. чкалова': 1,
#  'ул. вешняковская': 1,
#  'ул. нижегородская': 1,
#  'ул. гастелло': 1,
#  'ул. марии ульяновой': 1,
#  'проезд. черского': 1,
#  'ул. генерала ермолова': 1,
#  'пр-кт. солнцевский': 1,
#  'ул. улофа пальме': 1,
#  'наб. карамышевская': 1,
#  'ул. садовая-сухаревская': 1,
#  'ул. боровская': 1,
#  'пер. тепличный': 1,
#  'проезд. аэропорта': 1,
#  'ул. подольская': 1,
#  'ул. дудинка': 1,
#  'ул. вильнюсская': 1,
#  'ул. скобелевская': 1,
#  'ул. цандера': 1,
#  'д. яковлевское': 1,
#  'ул. старокачаловская': 1,
#  'сп мосрентген': 1,
#  'пер. песочный': 1,
#  'проезд. нагатинский 1-й': 1,
#  'п. ватутинки': 1,
#  'ул. поречная': 1,
#  'м. кузнецкий мост': 1,
#  'пер. варсонофьевский': 1,
#  'ул. планетная': 1,
#  'ул. братеевская': 1,
#  'пр-кт. нахимовский': 1,
#  'ул. аргуновская': 1,
#  'пер. гагаринский': 1,
#  'наб. преображенская': 1,
#  'пер. староконюшенный': 1,
#  'ул. самеда вургуна': 1,
#  'проезд. шмитовский': 1,
#  'ул. чичерина': 1,
#  'пер. ананьевский': 1,
#  'ул. старый гай': 1,
#  'ул. сельскохозяйственная': 1,
#  'сп марушкинское': 1,
#  'ул. радиальная 6-я': 1,
#  'пер. лучников': 1,
#  'х. брехово': 1,
#  'ул. 10-летия октября': 1,
#  'пер. фурманный': 1,
#  'ул. поликарпова': 1,
#  'ул. газопровод': 1,
#  'ул. нарвская': 1,
#  'пер. уланский': 1,
#  'пер. вокзальный': 1,
#  'пр-кт. комсомольский': 1,
#  'проезд. кочновский': 1,
#  'ул. изюмская': 1,
#  'ул. выборгская': 1,
#  'ул. лухмановская': 1,
#  'ул. седова': 1,
#  'пер. козловский б.': 1,
#  'ул. бронная б.': 1,
#  'северное измайлово': 1,
#  'ул. никитинская': 1,
#  'проезд. заревый': 1,
#  'пер. стромынский': 1,
#  'пер. климентовский': 1,
#  'ул. константина симонова': 1,
#  'ул. ереванская': 1,
#  'ул. барклая': 1,
#  'ул. тагильская': 1,
#  'пер. пресненский': 1,
#  'пр-кт. университетский': 1,
#  'ул. ращупкина': 1,
#  'ул. садовая-спасская': 1,
#  'ул. мясниковская 1-я': 1,
#  'ул. 8 марта': 1,
#  'ул. тихомирова': 1,
#  'м. библиотека им. ленина': 1,
#  'ул. волхонка': 1,
#  'ул. летчика бабушкина': 1,
#  'наб. фрунзенская': 1,
#  'ул. харьковская': 1,
#  'ул. тимура фрунзе': 1,
#  'п. матвеевское': 1,
#  'ул. каретный ряд': 1,
#  'ул. минусинская': 1,
#  'б-р. литовский': 1,
#  'ул. академика арцимовича': 1,
#  'ул. уссурийская': 1,
#  'ул. молодогвардейская': 1,
#  'ул. плеханова': 1,
#  'проезд. кожуховский 2-й': 1,
#  'ул. кулакова': 1,
#  'ул. домодедовская': 1,
#  'ш. сколковское': 1,
#  'ул. академика королева': 1,
#  'пер. леонтьевский': 1,
#  'ш. открытое': 1,
#  'дп. кокошкино': 1,
#  'ул. дачная': 1,
#  'ул. ферганская': 1,
#  'капотня': 1,
#  'кв-л. капотня 5-й': 1,
#  'ул. привольная': 1,
#  'пер. медовый': 1,
#  'пгт. акулово': 1,
#  'ул. губкина': 1,
#  'ул. зоологическая': 1,
#  'ул. главмосстроя': 1,
#  'ул. криворожская': 1,
#  'б-р. перервинский': 1,
#  'ул. мусоргского': 1,
#  'пер. серебряный': 1,
#  'проезд. петровско-разумовский': 1,
#  'ул. чусовская': 1,
#  'ул. беломорская': 1,
#  'ул. адмирала руднева': 1,
#  'ул. льва яшина': 1,
#  'д. десна': 1,
#  'пер. лазаревский': 1,
#  'проезд. погонный': 1,
#  'ул. октябрьская': 1,
#  'ул. реутовская': 1,
#  'ул. знаменские садки': 1,
#  'ул. паустовского': 1,
#  'ул. преображенский вал': 1,
#  'ул. андерсена (п десеновское)': 1,
#  'ул. таллинская': 1,
#  'ул. усачева': 1,
#  'ул. бусиновская горка': 1,
#  'восточное дегунино': 1,
#  'ул. академическая б.': 1,
#  'ул. никулинская': 1,
#  'ул. амундсена': 1,
#  'ул. жуковского': 1,
#  'бескудниковский': 1,
#  'ш. коровинское': 1,
#  'д. рассказовка': 1,
#  'ул. гризодубовой': 1,
#  'ул. просторная': 1,
#  'проезд. ореховый': 1,
#  'ул. сивашская': 1,
#  'ул. медиков': 1,
#  'ул. павла корчагина': 1,
#  'ул. новокосинская': 1,
#  'ул. зеленодольская': 1,
#  'ул. стасовой': 1,
#  'д. софьино': 1,
#  'ул. щербаковская': 1,
#  'ул. базовая': 1,
#  'ул. гражданская 3-я': 1,
#  'ул. куусинена': 1,
#  'ул. преображенская': 1,
#  'м. хорошёвская': 1,
#  'б-р. филевский': 1,
#  'ул. красногвардейская 3-я': 1,
#  'ул. армавирская': 1,
#  'тер. крюковская эстакада': 1,
#  'ул. чечулина': 1,
#  'ш. щелковское': 1,
#  'ул. булатниковская': 1,
#  'б-р. ореховый': 1,
#  'пер. смоленский 1-й': 1,
#  'алтуфьевский': 1,
#  'ул. стандартная': 1,
#  'ул. бурденко': 1,
#  'наб. даниловская': 1,
#  'ул. александры монаховой': 1,
#  'ул. академика ильюшина': 1,
#  'ул. верземнека': 1,
#  'пер. плетешковский': 1,
#  'ул. менжинского': 1,
#  'ул. беловежская': 1,
#  'ул. шипиловская': 1,
#  'ул. бутырская': 1,
#  'ул. климашкина': 1,
#  'ул. металлургов': 1,
#  'ул. солянка': 1,
#  'пер. грузинский': 1,
#  'ул. ярцевская': 1,
#  'ул. марксистская': 1,
#  'м. битцевский парк': 1,
#  'пер. татарский б.': 1,
#  'ул. молодежная': 1,
#  'мкр. родники': 1,
#  'д. сколково': 1,
#  'ул. крутицкий вал': 1,
#  'проезд. русанова': 1,
#  'ул. чапаева': 1,
#  'ул. летчика полагушина': 1,
#  'ул. минская': 1,
#  'б-р. смоленский': 1,
#  'проезд. донелайтиса': 1,
#  'пер. каретный ср.': 1,
#  'ул. судостроительная': 1,
#  'ул. кременчугская': 1,
#  'ул. веерная': 1,
#  'пр-кт. зеленый': 1,
#  'ул. байкальская': 1,
#  'ул. капотня': 1,
#  'ул. рочдельская': 1,
#  'пер. дегтярный': 1,
#  'ул. брусилова': 1,
#  'пер. молочный': 1,
#  'ул. татьяны макаровой': 1,
#  'ул. игральная': 1,
#  'ул. бартеневская': 1,
#  'ул. сальвадора альенде': 1,
#  'п. дск мичуринец': 1,
#  'ул. энгельса': 1,
#  'мкр. чертаново северное': 1,
#  'пер. ташкентский': 1,
#  'ул. спасская б.': 1,
#  'б-р. никитский': 1,
#  'ул. алексея свиридова': 1,
#  'пер. козицкий': 1,
#  'ул. фридриха энгельса': 1,
#  ...}

# %%
# prepare sorted list of split words from above
word_counter2={}
for x in [x.split(' ')[0] for x in unique_values if ' ' in x]:
    if x.lower() not in word_counter2:
        word_counter2[x.lower()] = 0
    word_counter2[x.lower()] +=1

print(list(dict(sorted(word_counter2.items(), key=lambda item: item[1], reverse=True))))
# Out:
# ['ул.', 'м.', 'пер.', 'п.', 'мцк', 'проезд.', 'пр-кт.', 'д.', 'б-р.', 'ш.', 'сп', 'наб.', 'пл.', 'г.', 'северное', 'мкр.', 'южное', 'чертаново', 'с.', 'аллея.', 'орехово-борисово', 'бирюлёво', 'восточное', 'новая', 'филёвский', 'тёплый', 'рп.', 'марьина', 'проспект', 'западное', 'нагатинский', 'соколиная', 'го', 'х.', 'дп.', 'кв-л.', 'пгт.', 'тер.']

# %% [markdown]
# ##### date

# %%
# day
def get_day(field):
    try:
        day = int(field[0].split()[0])
        return day
    except:
        return None

# %%
# month
def get_months(field):
    try:
        month = field[0].split()[1]
        if len(month) < 2:
            return None
        else:
            return month.lower()
    
    except:
        return None

# %%
months_ru = list(train['date'].map(get_months).value_counts().index.values)
months_ru
# Out:
# ['мая',
#  'апреля',
#  'марта',
#  'февраля',
#  'января',
#  'октября',
#  'декабря',
#  'ноября',
#  'сентября',
#  'августа',
#  'июля',
#  'июня']

# %%
# month translation
months_pl = ['maj', 'kwiecień', 'marzec', 'luty', 'styczeń', 'październik', 'grudzień', 'listopad', 'wrzesień', 'sierpień', 'lipiec', 'czerwiec']

# %%
months_k_v = dict(zip(months_ru, months_pl))
months_k_v
# Out:
# {'мая': 'maj',
#  'апреля': 'kwiecień',
#  'марта': 'marzec',
#  'февраля': 'luty',
#  'января': 'styczeń',
#  'октября': 'październik',
#  'декабря': 'grudzień',
#  'ноября': 'listopad',
#  'сентября': 'wrzesień',
#  'августа': 'sierpień',
#  'июля': 'lipiec',
#  'июня': 'czerwiec'}

# %%
train['date'].head(50)
# for x in train['date'].iteritems():
#     print(x)
# Out:
# 0     [23 февраля 2018, 133, (+2 за сегодня), Обновл...
# 1                 [сегодня в 04:52, 3, (+3 за сегодня)]
# 2       [5 марта, 6, (+1 за сегодня), Обновлено 15 мая]
# 3     [22 мая 2018, 60, (+2 за сегодня), Обновлено 1...
# 4     [26 декабря 2018, 13, (+1 за сегодня), Обновле...
# 5                          [16 мая, 8, (+1 за сегодня)]
# 6     [13 апреля, 8, (+1 за сегодня), Обновлено 17 мая]
# 7     [10 февраля, 12, (+1 за сегодня), Обновлено 15...
# 8                          [14 мая, 6, (+1 за сегодня)]
# 9      [26 марта, 9, (+3 за сегодня), Обновлено 18 мая]
# 10       [10 мая, 2, (+1 за сегодня), Обновлено 16 мая]
# 11        [9 мая, 3, (+1 за сегодня), Обновлено 16 мая]
# 12    [23 декабря 2018, 24, (+2 за сегодня), Обновле...
# 13       [10 мая, 2, (+1 за сегодня), Обновлено 16 мая]
# 14    [17 апреля, 4, (+1 за сегодня), Обновлено 16 мая]
# 15       [12 мая, 2, (+2 за сегодня), Обновлено 18 мая]
# 16                [сегодня в 04:55, 2, (+2 за сегодня)]
# 17                         [16 мая, 5, (+1 за сегодня)]
# 18                [сегодня в 04:57, 3, (+3 за сегодня)]
# 19    [12 февраля, 15, (+1 за сегодня), Обновлено 13...
# 20    [19 апреля, 8, (+2 за сегодня), Обновлено 15 мая]
# 21    [28 декабря 2018, 41, (+2 за сегодня), Обновле...
# 22    [26 января, 14, (+2 за сегодня), Обновлено 18 ...
# 23    [5 марта, 5, (+2 за сегодня), Обновлено вчера ...
# 24    [24 ноября 2018, 26, (+1 за сегодня), Обновлен...
# 25    [10 декабря 2018, 23, (+1 за сегодня), Обновле...
# 26    [6 октября 2018, 24, (+2 за сегодня), Обновлен...
# 27    [5 февраля, 21, (+1 за сегодня), Обновлено 13 ...
# 28                         [17 мая, 2, (+1 за сегодня)]
# 29                         [16 мая, 4, (+1 за сегодня)]
# 30    [28 апреля, 5, (+1 за сегодня), Обновлено 17 мая]
# 31    [17 января, 30, (+1 за сегодня), Обновлено 13 ...
# 32    [22 ноября 2018, 20, (+1 за сегодня), Обновлен...
# 33    [16 января, 18, (+2 за сегодня), Обновлено 14 ...
# 34    [26 апреля, 3, (+1 за сегодня), Обновлено 16 мая]
# 35    [7 апреля, 12, (+1 за сегодня), Обновлено 17 мая]
# 36    [25 апреля, 5, (+1 за сегодня), Обновлено 16 мая]
# 37    [22 января, 20, (+1 за сегодня), Обновлено 15 ...
# 38     [6 марта, 17, (+2 за сегодня), Обновлено 18 мая]
# 39        [4 мая, 1, (+1 за сегодня), Обновлено 17 мая]
# 40                         [17 мая, 2, (+1 за сегодня)]
# 41                         [13 мая, 4, (+1 за сегодня)]
# 42     [6 марта, 15, (+1 за сегодня), Обновлено 18 мая]
# 43                         [17 мая, 2, (+1 за сегодня)]
# 44     [4 марта, 13, (+1 за сегодня), Обновлено 15 мая]
# 45                         [13 мая, 6, (+1 за сегодня)]
# 46       [10 мая, 3, (+2 за сегодня), Обновлено 16 мая]
# 47    [20 ноября 2018, 28, (+1 за сегодня), Обновлен...
# 48       [11 мая, 3, (+2 за сегодня), Обновлено 17 мая]
# 49    [21 марта, 9, (+2 за сегодня), Обновлено вчера...
# Name: date, dtype: object

# %%
# date plus
   
def get_date_plus(field):
    
    if len(field)>2 and field[2][0]=='(':
        lista = list(field[2].split()[0])
#         print(lista)
        int_list = []
        for i in lista:
            try:
                int_list.append(int(i))
                
            except:
                continue
        
        if len(int_list)<2:
            
            return int_list[0]
        
        else:
            strings=[str(integer) for integer in int_list]
            a_string=''.join(strings)
            an_integer=int(a_string)
            
            return an_integer

        

        
# print(date_plus(['12 февраля', '15', '(+12 за сегодня)', 'Обновлено 13 мая']))

train['date'].map(lambda x: x[3] if len(x)>3 else None).value_counts()
# train['date'].map(get_date_plus).value_counts()
# Out:
# Обновлено 15 мая             8868
# Обновлено 14 мая             7333
# Обновлено 18 мая             5412
# Обновлено 17 мая             4557
# Обновлено 16 мая             4167
#                              ...
# Обновлено вчера в 11:17         1
# Обновлено вчера в 09:58         1
# Обновлено сегодня в 02:56       1
# Обновлено вчера в 10:19         1
# Обновлено 26 апреля             1
# Name: date, Length: 244, dtype: int64

# %%
# is updated ?
def get_updated(field):
    
    lista = [int('обновлено' in x.lower()) for x in field]
    
    return int(1 in lista)

# updated(['18 февраля', '14', '(+2 за сегодня)', 'Обновлено 14 мая'])
train['date'].map(get_updated).head(100)
# Out:
# 0     1
# 1     0
# 2     1
# 3     1
# 4     1
#      ..
# 95    1
# 96    1
# 97    0
# 98    0
# 99    1
# Name: date, Length: 100, dtype: int64

# %% [markdown]
# ##### geo block

# %%
train['geo_block'].head()
# Out:
# 0                               [г. Москва, г. Москва]
# 1    [Новая Москва, п. Сосенское, п. Коммунарка, Юж...
# 2         [г. Москва, ул Поляны, г. Москва, ул Поляны]
# 3             [г. Москва, Беговой, г. Москва, Беговой]
# 4    [г. Москва, Филёвский Парк, г. Москва, Филёвск...
# Name: geo_block, dtype: object

# %%
train['geo_block'].head(100)
# Out:
# 0                                [г. Москва, г. Москва]
# 1     [Новая Москва, п. Сосенское, п. Коммунарка, Юж...
# 2          [г. Москва, ул Поляны, г. Москва, ул Поляны]
# 3              [г. Москва, Беговой, г. Москва, Беговой]
# 4     [г. Москва, Филёвский Парк, г. Москва, Филёвск...
#                             ...
# 95    [г. Москва, Останкинский, г. Москва, Останкинс...
# 96    [г. Москва, Филёвский Парк, г. Москва, Филёвск...
# 97    [г. Москва, Хорошёво-Мнёвники, ул Народного Оп...
# 98         [г. Москва, Зябликово, г. Москва, Зябликово]
# 99           [г. Москва, Бибирево, г. Москва, Бибирево]
# Name: geo_block, Length: 100, dtype: object

# %%
# get most popular localizations (up to 200)
geo_dict = {}
unique_values = []
for lista in train['geo_block'].values:
    for word in lista:
        if word.lower() not in geo_dict:
            geo_dict[word.lower()] = 0
            unique_values.append(word.lower())
        geo_dict[word.lower()] +=1

# geo_dict
# sorted(geo_dict.items(), key=lambda item: item[1], reverse=True)[:200]
list(dict(sorted(geo_dict.items(), key=lambda item: item[1], reverse=True)))[:200]
# Out:
# ['г. москва',
#  'новая москва',
#  'п. сосенское',
#  'п. коммунарка',
#  'южное бутово',
#  'хорошёво-мнёвники',
#  'ул дыбенко',
#  'ул лобачевского',
#  'п. московский',
#  'филёвский парк',
#  'тропарёво-никулино',
#  'ховрино',
#  'раменки',
#  'люблино',
#  'ул верхние поля',
#  'некрасовка',
#  'тёплый стан',
#  'кунцево',
#  'орехово-борисово южное',
#  'г. московский',
#  'выхино-жулебино',
#  'д. николо-хованское',
#  'зябликово',
#  'рязанский',
#  'п. внуковское',
#  'марьино',
#  'лефортово',
#  'пресненский',
#  'пр-кт мира',
#  'ул зорге',
#  'ул поляны',
#  'отрадное',
#  'г. зеленоград',
#  'свиблово',
#  'дмитровский',
#  'тимирязевский',
#  'бутырский',
#  'останкинский',
#  'ул берзарина',
#  'п. филимонковское',
#  'ростокино',
#  'солнцево',
#  'черёмушки',
#  'беговой',
#  'головинский',
#  'марьина роща',
#  'западное дегунино',
#  'щукино',
#  'митино',
#  'ул римского-корсакова',
#  'ул золоторожский вал',
#  'ул академика павлова',
#  'ул генерала белова',
#  'хамовники',
#  'южное медведково',
#  'измайлово',
#  'д. румянцево',
#  'крылатское',
#  'красносельский',
#  'даниловский',
#  'ул красная сосна',
#  'п. свиблово',
#  'ярославский',
#  'крюково',
#  'ул сергея макеева',
#  'п. некрасовка',
#  'пр-кт академика сахарова',
#  'д. староселье',
#  'северный',
#  'п. десеновское',
#  'п. рязановское',
#  'с. остафьево',
#  'ул ляпидевского',
#  'басманный',
#  'ново-переделкино',
#  'ул расплетина',
#  'проезд серебрякова',
#  'левобережный',
#  'тверской',
#  'ул народного ополчения',
#  'текстильщики',
#  'п. марушкинское',
#  'хорошёвский',
#  'алексеевский',
#  'таганский',
#  'северное медведково',
#  'ул ефремова',
#  'дорогомилово',
#  'чертаново южное',
#  'ул вавилова',
#  'чертаново центральное',
#  'лосиноостровский',
#  'д. столбово',
#  'аэропорт',
#  'замоскворечье',
#  'северное бутово',
#  'новогиреево',
#  'ул петра алексеева',
#  'бабушкинский',
#  'нижегородский',
#  'д. саларьево',
#  'ш дмитровское',
#  'ул новый арбат',
#  'лианозово',
#  'нагорный',
#  'пр-кт маршала жукова',
#  'якиманка',
#  'богородское',
#  'ул бочкова',
#  'вешняки',
#  'д. 1, к. 1',
#  'соколиная гора',
#  'северное тушино',
#  'п. первомайское',
#  'п. воскресенское',
#  'б-р генерала карбышева',
#  'савёловский',
#  'д. 32',
#  'ул земляной вал',
#  'царицыно',
#  'ул михайлова',
#  'коньково',
#  'арбат',
#  'академический',
#  'пер хилков',
#  'ул нежинская',
#  'восточное измайлово',
#  'ул генерала глаголева',
#  'пер холодильный',
#  'д. 1, к. 3',
#  'ул паршина',
#  'ул фадеева',
#  'ул юннатов',
#  'ул орджоникидзе',
#  'проспект вернадского',
#  'мещанский',
#  'д. язово',
#  'д. говорово',
#  'ул маршала катукова',
#  'ул циолковского',
#  'ул арбат',
#  'пер богословский',
#  'кузьминки',
#  'бибирево',
#  'строгино',
#  'перово',
#  'сокол',
#  'покровское-стрешнево',
#  'пер коробейников',
#  'ясенево',
#  'пл курского вокзала',
#  'нагатинский затон',
#  'ул адмирала макарова',
#  'орехово-борисово северное',
#  'п. щаповское',
#  'ул речников',
#  'пер басманный',
#  'г. щербинка',
#  'г. троицк',
#  'ул фабрициуса',
#  'москворечье-сабурово',
#  'ул мельникова',
#  'войковский',
#  'д. ямонтово',
#  'ул усиевича',
#  'южнопортовый',
#  'пр-кт 40 лет октября',
#  'ул серпуховский вал',
#  'ул демьяна бедного',
#  'гагаринский',
#  'пр-кт вернадского',
#  'ул палиха',
#  'п. дорожно-ремонтного пункта 3',
#  'фили-давыдково',
#  'нагатино-садовники',
#  'ул черняховского',
#  'пер гороховский',
#  'пер тессинский',
#  'ул пресненский вал',
#  'сокольники',
#  'наб павелецкая',
#  'ул 40 лет октября',
#  'пер еропкинский',
#  'ул софьи ковалевской',
#  'можайский',
#  'ул коминтерна',
#  'ул новая дорога',
#  'пер докучаев',
#  'донской',
#  'чертаново северное',
#  'п. новофедоровское',
#  'ул комдива орлова',
#  'ул багрицкого',
#  'пер даев',
#  'преображенское',
#  'ул василисы кожиной',
#  'ул викторенко',
#  'пер подсосенский',
#  'ул маресьева',
#  'ул мусы джалиля']

# %%
# help functions
def get_security_len(field):
    try:
        return len(field.strip())
    
    except:
        return None

def get_security_wrd_cnt(field):
    try:
        return len(field.split())
    
    except:
        return None
    
def get_owner(field):
    if len(field) > 0:
        return str(field[0]).strip().lower()
    else:
        return None
    
def get_owner_len(field):
    try:
        return len(field)
    except:
        return None  
    
def get_owner_cnt(field):
    try:
        return len(field.split())
    except:
        return None  
    
def get_lower(field):
    try:
        return field.lower()
    
    except:
        return None
    
# day
def get_day(field):
    try:
        day = int(field[0].split()[0])
        return day
    except:
        return None
    
# month
def get_months(field):
    try:
        month = field[0].split()[1]
        if len(month) < 2:
            return None
        else:
            return month.lower()
    
    except:
        return None
    
# date plus
def get_date_plus(field):
    
    if len(field)>2 and field[2][0]=='(':
        lista = list(field[2].split()[0])
#         print(lista)
        int_list = []
        for i in lista:
            try:
                int_list.append(int(i))
                
            except:
                continue
        
        if len(int_list)<2:
            
            return int_list[0]
        
        else:
            strings=[str(integer) for integer in int_list]
            a_string=''.join(strings)
            an_integer=int(a_string)
            
            return an_integer
        
# updated ?
def get_updated(field):
    
    lista = [int('обновлено' in x.lower()) for x in field]
    
    return int(1 in lista)


# geoblock
def extract_geoblock(vals):
    vals = vals[: int(len(vals) / 2)]
    return {"geo_block_{}".format(idx):val.strip().lower() for idx, val in enumerate(vals)}


# size decrease and fillna
def size_decrease(df):

    df=df.fillna(-1)
    int8_max = 127
    int16_max = 32767
    int32_max = 2147483647
    
    for x in df[[col for col in df.columns if col not in['price', 'id']]]:
        if df[x].dtype != 'O':
            
            if df[x].max() <= int8_max:
                df[x]=df[x].astype('int8')
            
            elif df[x].max() <= int16_max:
                df[x]=df[x].astype('int16')
            
            else:
                df[x]=df[x].astype('int32')
                
    return df

# %%
# feature enfineering

def long_text_features(train=train, test=test, bread_main_parts=50):
    
    df_all = pd.concat([train, test], axis=0)
    
    df_all['breadcrumbs_w_cnt'] = df_all['breadcrumbs'].map(lambda x: len(x)).astype('int8')
    df_all['breadcrumbs_joined'] = df_all['breadcrumbs'].map(lambda x: ', '.join(x).lower())
    
    # główne człony breadcrumbs
    word_counter = {}
    unique_values = []
    for lista in df_all['breadcrumbs'].values:
        for word in lista:
            
            word = word.lower().strip().strip(',')
            
            if word not in word_counter:
                word_counter[word] = 0
                unique_values.append(word)
            word_counter[word] +=1

    breadcrumbs_main = list(dict(sorted(word_counter.items(), key=lambda item: item[1], reverse=True)))[:bread_main_parts]
    for i in breadcrumbs_main:
        df_all['breadcrumbs_' + i] = df_all['breadcrumbs_joined'].map(lambda x: int(i.lower().strip().strip(',') in  x.lower()))
        
    # skróty breadcrumbs
    
    word_counter2={}
    for word in [word.split(' ')[0] for x in unique_values if ' ' in x]:
        
        word = word.lower().strip().strip(',')
        
        if word not in word_counter2:
            word_counter2[word] = 0
        word_counter2[word] +=1

    breadcrumbs_shortcuts = list(dict(sorted(word_counter2.items(), key=lambda item: item[1], reverse=True)))
    
    for i in breadcrumbs_shortcuts:
        df_all['breadcrumbs_' + i] = df_all['breadcrumbs_joined'].map(lambda x: int(i.lower().strip() in  x.lower()))
        
    
    
    # date + factorize month ? wyciągnąć rok ???
    df_all['day'] = df_all['date'].map(get_day)
    
    months_ru = ['мая', 'апреля', 'марта', 'февраля', 'января', 'октября', 'декабря', 'ноября', 'сентября', 'августа', 'июля', 'июня']
    months_pl = ['maj', 'kwiecień', 'marzec', 'luty', 'styczeń', 'październik', 'grudzień', 'listopad', 'wrzesień', 'sierpień', 'lipiec', 'czerwiec']
    months_k_v = dict(zip(months_ru, months_pl))
    
   
    df_all['date_month'] = df_all['date'].map(get_months)
    
    df_all['date_some_number'] = df_all['date'].map(lambda x: x[1])
    df_all['date_plus'] = df_all['date'].map(get_date_plus)
    df_all['date_updated'] = df_all['date'].map(get_updated)
    
    
    
    # geo_block
    df_all['geo_block_cnt'] = df_all['geo_block'].map(lambda x: len(x))
    df_all['geo_block_joined'] = df_all['geo_block'].map(lambda x: ', '.join(x).lower())
    
    geo_dict = {}
    unique_values = []
    for lista in df_all['geo_block'].values:
        for word in lista:
            word = word.lower().strip().strip(',')
            if word.lower() not in geo_dict:
                geo_dict[word.lower()] = 0
                unique_values.append(word.lower())
            geo_dict[word.lower()] +=1


    geo_locations=list(dict(sorted(geo_dict.items(), key=lambda item: item[1], reverse=True)))[:200]

    for i in geo_locations:
        df_all['geo_block_' + i] = df_all['geo_block_joined'].map(lambda x: int(i.lower().strip().strip(',') in x.lower()))
        
    # geo block Vladimira
    
    df_geo_block = df_all["geo_block"].map(extract_geoblock).apply(pd.Series)
    df_all = pd.concat([df_all, df_geo_block], axis=1)

    feats_geo_block = [ x for x in df_geo_block.columns]
    for f in feats_geo_block:
        df_all["{}_cat".format(f)] = df_all[f].factorize()[0]
    
    
    # owner dokończyć !!
    df_all['owner'] = df_all['owner'].map(get_owner)
    df_all['owner_len'] = df_all['owner'].map(get_owner_len)
    df_all['owner_cnt'] = df_all['owner'].map(get_owner_cnt)
    
    
    # security
    df_all['security_wrd_cnt'] = df_all['Security:'].map(get_security_wrd_cnt)
    df_all['security_len'] = df_all['Security:'].map(get_security_len)
    
    word_counter = {}
    unique_values = []
    for word in ' '.join([str(x) for x in df_all['Security:'][df_all['Security:'].notnull()].values]).split():

        word = word.lower().strip().strip(',')
    
        if word not in word_counter:
            word_counter[word] = 0
            unique_values.append(word)
        word_counter[word.lower()] +=1

    security_words=list(dict(sorted(word_counter.items(), key=lambda item: item[1], reverse=True)))[:20]
    
    for i in security_words:
        df_all['security_' + i] = df_all['Security:'].map(lambda x: int(i.lower().strip() in str(x).lower()))
    
    return df_all

def short_text_features(df_all, features):
    
    # opracować to , co poniżej!!!!!
    # columns from 6 to end
    created_cols = []
    for col in df_all[features].columns:
        
        df_all[col] = df_all[col].map(get_lower)
        df_all[col] = df_all[col].fillna(-1)
        
        if len(df_all[col].unique()) > 2:
            
    
        
            labels_by_mean = [str(x).lower() for x in df_all[[col, 'price']][False == df_all['price'].isnull()].fillna(-1).groupby(col).agg('mean').reset_index().sort_values('price')[col].values]
            labels_by_median = [str(x).lower() for x in df_all[[col, 'price']][False == df_all['price'].isnull()].fillna(-1).groupby(col).agg('median').reset_index().sort_values('price')[col].values]
        
            type_values = [x for x in range(1, len(labels_by_mean)+1)] # mean or median tu obojętnie
        
            lab_rep_dict_mean = dict(zip(labels_by_mean, type_values))
            lab_rep_dict_median = dict(zip(labels_by_median, type_values))
        
            df_all['fact_{}_mean'.format(col)] = df_all[col].replace(lab_rep_dict_mean)
            df_all['fact_{}_median'.format(col)] = df_all[col].replace(lab_rep_dict_median)
            
            created_cols.append('fact_{}_mean'.format(col))
            created_cols.append('fact_{}_median'.format(col))
        
        else:
            
            df_all = pd.get_dummies(data=df_all, prefix='OH_{}'.format(col), columns=[col])
            
    
    df_all['date_some_number'] = df_all['date_some_number'].astype('int32')
#     df_all['fact_Type of the building:_mean'] = df_all['fact_Type of the building:_mean'].astype('int8')
#     df_all['fact_Type of the building:_median'] = df_all['fact_Type of the building:_median'].astype('int8')                            
    
    # split
    df_train, df_test = df_all[False == df_all['price'].isnull()], df_all[df_all['price'].isnull()]
    
    # size decrease
    df_train = size_decrease(df_train)
    df_test = size_decrease(df_test)
    
    return df_train, df_test.drop(['price'], axis=1)

# %%
# read data again
raw_train = pd.read_pickle('/kaggle/input/pmlprices-raw-data/4property.train.pkl')
raw_test = pd.read_pickle('/kaggle/input/pmlprices-raw-data/4property.test.pkl')

# %%
# feature engineering
features = ['Building type:', 'Object type:', 'Ad type:', 'Commission agent:',
       'Construction phase:', 'Housing class:', 'Elevator:',
       'Bathroom type:', 'Balcony type:', 'Mortgage possible:',
       'The view from the window:', 'Garbage chute:', 'Repair:',
       'Fridge:', 'Phone:', 'Furniture:', 'Free layout:',
       'It is possible to bargain:', 'Floor covering:', 'Room type:',
       'Internet:', 'Kitchen furniture:', 'TV:', 'Washing machine:',
       'Foundation type:', 'Overlap type:', 'Type of the building:',
       'Playground:', 'Class:', 'date_month']


start = time.time()
df_all = long_text_features(train=raw_train, test=raw_test, bread_main_parts=50)

train, test = short_text_features(df_all, features)

end = time.time()
print(end - start)
# Out:
# 61.72240495681763

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45694 entries, 0 to 45693
# Data columns (total 377 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   breadcrumbs                               45694 non-null  object
#  1   date                                      45694 non-null  object
#  2   geo_block                                 45694 non-null  object
#  3   owner                                     45694 non-null  object
#  4   price                                     45694 non-null  float64
#  5   Security:                                 45694 non-null  object
#  6   Building type:                            45694 non-null  object
#  7   Object type:                              45694 non-null  object
#  8   Ad type:                                  45694 non-null  object
#  9   Construction phase:                       45694 non-null  object
#  10  Housing class:                            45694 non-null  object
#  11  Bathroom type:                            45694 non-null  object
#  12  Balcony type:                             45694 non-null  object
#  13  The view from the window:                 45694 non-null  object
#  14  Repair:                                   45694 non-null  object
#  15  Floor covering:                           45694 non-null  object
#  16  Room type:                                45694 non-null  object
#  17  Foundation type:                          45694 non-null  object
#  18  Overlap type:                             45694 non-null  object
#  19  Type of the building:                     45694 non-null  object
#  20  id                                        45694 non-null  float64
#  21  breadcrumbs_w_cnt                         45694 non-null  int8
#  22  breadcrumbs_joined                        45694 non-null  object
#  23  breadcrumbs_москва                        45694 non-null  int8
#  24  breadcrumbs_мцк крымская                  45694 non-null  int8
#  25  breadcrumbs_новая москва                  45694 non-null  int8
#  26  breadcrumbs_мцк кутузовская               45694 non-null  int8
#  27  breadcrumbs_п. сосенское                  45694 non-null  int8
#  28  breadcrumbs_мцк шелепиха                  45694 non-null  int8
#  29  breadcrumbs_мцк лужники                   45694 non-null  int8
#  30  breadcrumbs_мцк коптево                   45694 non-null  int8
#  31  breadcrumbs_п. коммунарка                 45694 non-null  int8
#  32  breadcrumbs_мцк хорошёво                  45694 non-null  int8
#  33  breadcrumbs_южное бутово                  45694 non-null  int8
#  34  breadcrumbs_мцк зил                       45694 non-null  int8
#  35  breadcrumbs_мцк шоссе энтузиастов         45694 non-null  int8
#  36  breadcrumbs_м. бунинская аллея            45694 non-null  int8
#  37  breadcrumbs_мцк нижегородская             45694 non-null  int8
#  38  breadcrumbs_мцк угрешская                 45694 non-null  int8
#  39  breadcrumbs_мцк владыкино                 45694 non-null  int8
#  40  breadcrumbs_хорошёво-мнёвники             45694 non-null  int8
#  41  breadcrumbs_мцк лихоборы                  45694 non-null  int8
#  42  breadcrumbs_мцк ботанический сад          45694 non-null  int8
#  43  breadcrumbs_ул. дыбенко                   45694 non-null  int8
#  44  breadcrumbs_мцк балтийская                45694 non-null  int8
#  45  breadcrumbs_ул. лобачевского              45694 non-null  int8
#  46  breadcrumbs_мцк зорге                     45694 non-null  int8
#  47  breadcrumbs_п. московский                 45694 non-null  int8
#  48  breadcrumbs_м. выхино                     45694 non-null  int8
#  49  breadcrumbs_филёвский парк                45694 non-null  int8
#  50  breadcrumbs_м. октябрьское поле           45694 non-null  int8
#  51  breadcrumbs_мцк ростокино                 45694 non-null  int8
#  52  breadcrumbs_ховрино                       45694 non-null  int8
#  53  breadcrumbs_тропарёво-никулино            45694 non-null  int8
#  54  breadcrumbs_м. ховрино                    45694 non-null  int8
#  55  breadcrumbs_раменки                       45694 non-null  int8
#  56  breadcrumbs_м. саларьево                  45694 non-null  int8
#  57  breadcrumbs_м. пятницкое шоссе            45694 non-null  int8
#  58  breadcrumbs_люблино                       45694 non-null  int8
#  59  breadcrumbs_ул. верхние поля              45694 non-null  int8
#  60  breadcrumbs_м. братиславская              45694 non-null  int8
#  61  breadcrumbs_некрасовка                    45694 non-null  int8
#  62  breadcrumbs_м. ботанический сад           45694 non-null  int8
#  63  breadcrumbs_м. теплый стан                45694 non-null  int8
#  64  breadcrumbs_м. рязанский проспект         45694 non-null  int8
#  65  breadcrumbs_тёплый стан                   45694 non-null  int8
#  66  breadcrumbs_мцк локомотив                 45694 non-null  int8
#  67  breadcrumbs_кунцево                       45694 non-null  int8
#  68  breadcrumbs_мцк деловой центр             45694 non-null  int8
#  69  breadcrumbs_м. домодедовская              45694 non-null  int8
#  70  breadcrumbs_орехово-борисово южное        45694 non-null  int8
#  71  breadcrumbs_г. московский                 45694 non-null  int8
#  72  breadcrumbs_м. раменки                    45694 non-null  int8
#  73  breadcrumbs_ул.                           45694 non-null  int8
#  74  day                                       45694 non-null  int8
#  75  date_month                                45694 non-null  object
#  76  date_some_number                          45694 non-null  int16
#  77  date_plus                                 45694 non-null  int8
#  78  date_updated                              45694 non-null  int8
#  79  geo_block_cnt                             45694 non-null  int8
#  80  geo_block_joined                          45694 non-null  object
#  81  geo_block_г. москва                       45694 non-null  int8
#  82  geo_block_новая москва                    45694 non-null  int8
#  83  geo_block_п. сосенское                    45694 non-null  int8
#  84  geo_block_п. коммунарка                   45694 non-null  int8
#  85  geo_block_южное бутово                    45694 non-null  int8
#  86  geo_block_хорошёво-мнёвники               45694 non-null  int8
#  87  geo_block_ул дыбенко                      45694 non-null  int8
#  88  geo_block_ул лобачевского                 45694 non-null  int8
#  89  geo_block_п. московский                   45694 non-null  int8
#  90  geo_block_филёвский парк                  45694 non-null  int8
#  91  geo_block_ховрино                         45694 non-null  int8
#  92  geo_block_тропарёво-никулино              45694 non-null  int8
#  93  geo_block_раменки                         45694 non-null  int8
#  94  geo_block_люблино                         45694 non-null  int8
#  95  geo_block_ул верхние поля                 45694 non-null  int8
#  96  geo_block_некрасовка                      45694 non-null  int8
#  97  geo_block_тёплый стан                     45694 non-null  int8
#  98  geo_block_кунцево                         45694 non-null  int8
#  99  geo_block_орехово-борисово южное          45694 non-null  int8
#  100 geo_block_г. московский                   45694 non-null  int8
#  101 geo_block_выхино-жулебино                 45694 non-null  int8
#  102 geo_block_д. николо-хованское             45694 non-null  int8
#  103 geo_block_зябликово                       45694 non-null  int8
#  104 geo_block_рязанский                       45694 non-null  int8
#  105 geo_block_п. внуковское                   45694 non-null  int8
#  106 geo_block_марьино                         45694 non-null  int8
#  107 geo_block_лефортово                       45694 non-null  int8
#  108 geo_block_пресненский                     45694 non-null  int8
#  109 geo_block_пр-кт мира                      45694 non-null  int8
#  110 geo_block_ул зорге                        45694 non-null  int8
#  111 geo_block_ул поляны                       45694 non-null  int8
#  112 geo_block_отрадное                        45694 non-null  int8
#  113 geo_block_г. зеленоград                   45694 non-null  int8
#  114 geo_block_свиблово                        45694 non-null  int8
#  115 geo_block_дмитровский                     45694 non-null  int8
#  116 geo_block_тимирязевский                   45694 non-null  int8
#  117 geo_block_бутырский                       45694 non-null  int8
#  118 geo_block_ул берзарина                    45694 non-null  int8
#  119 geo_block_останкинский                    45694 non-null  int8
#  120 geo_block_западное дегунино               45694 non-null  int8
#  121 geo_block_черёмушки                       45694 non-null  int8
#  122 geo_block_п. филимонковское               45694 non-null  int8
#  123 geo_block_солнцево                        45694 non-null  int8
#  124 geo_block_беговой                         45694 non-null  int8
#  125 geo_block_головинский                     45694 non-null  int8
#  126 geo_block_ростокино                       45694 non-null  int8
#  127 geo_block_марьина роща                    45694 non-null  int8
#  128 geo_block_щукино                          45694 non-null  int8
#  129 geo_block_митино                          45694 non-null  int8
#  130 geo_block_ул римского-корсакова           45694 non-null  int8
#  131 geo_block_ул золоторожский вал            45694 non-null  int8
#  132 geo_block_хамовники                       45694 non-null  int8
#  133 geo_block_измайлово                       45694 non-null  int8
#  134 geo_block_крылатское                      45694 non-null  int8
#  135 geo_block_южное медведково                45694 non-null  int8
#  136 geo_block_ул академика павлова            45694 non-null  int8
#  137 geo_block_ул генерала белова              45694 non-null  int8
#  138 geo_block_красносельский                  45694 non-null  int8
#  139 geo_block_д. румянцево                    45694 non-null  int8
#  140 geo_block_даниловский                     45694 non-null  int8
#  141 geo_block_ул красная сосна                45694 non-null  int8
#  142 geo_block_крюково                         45694 non-null  int8
#  143 geo_block_п. некрасовка                   45694 non-null  int8
#  144 geo_block_п. свиблово                     45694 non-null  int8
#  145 geo_block_ярославский                     45694 non-null  int8
#  146 geo_block_ул сергея макеева               45694 non-null  int8
#  147 geo_block_пр-кт академика сахарова        45694 non-null  int8
#  148 geo_block_северный                        45694 non-null  int8
#  149 geo_block_д. староселье                   45694 non-null  int8
#  150 geo_block_п. рязановское                  45694 non-null  int8
#  151 geo_block_п. десеновское                  45694 non-null  int8
#  152 geo_block_проезд серебрякова              45694 non-null  int8
#  153 geo_block_с. остафьево                    45694 non-null  int8
#  154 geo_block_ул ляпидевского                 45694 non-null  int8
#  155 geo_block_басманный                       45694 non-null  int8
#  156 geo_block_ул расплетина                   45694 non-null  int8
#  157 geo_block_тверской                        45694 non-null  int8
#  158 geo_block_ново-переделкино                45694 non-null  int8
#  159 geo_block_текстильщики                    45694 non-null  int8
#  160 geo_block_ул народного ополчения          45694 non-null  int8
#  161 geo_block_хорошёвский                     45694 non-null  int8
#  162 geo_block_левобережный                    45694 non-null  int8
#  163 geo_block_алексеевский                    45694 non-null  int8
#  164 geo_block_п. марушкинское                 45694 non-null  int8
#  165 geo_block_чертаново южное                 45694 non-null  int8
#  166 geo_block_ул ефремова                     45694 non-null  int8
#  167 geo_block_таганский                       45694 non-null  int8
#  168 geo_block_северное медведково             45694 non-null  int8
#  169 geo_block_чертаново центральное           45694 non-null  int8
#  170 geo_block_дорогомилово                    45694 non-null  int8
#  171 geo_block_ул вавилова                     45694 non-null  int8
#  172 geo_block_аэропорт                        45694 non-null  int8
#  173 geo_block_лосиноостровский                45694 non-null  int8
#  174 geo_block_д. столбово                     45694 non-null  int8
#  175 geo_block_замоскворечье                   45694 non-null  int8
#  176 geo_block_новогиреево                     45694 non-null  int8
#  177 geo_block_северное бутово                 45694 non-null  int8
#  178 geo_block_бабушкинский                    45694 non-null  int8
#  179 geo_block_ш дмитровское                   45694 non-null  int8
#  180 geo_block_ул петра алексеева              45694 non-null  int8
#  181 geo_block_д. саларьево                    45694 non-null  int8
#  182 geo_block_нижегородский                   45694 non-null  int8
#  183 geo_block_ул новый арбат                  45694 non-null  int8
#  184 geo_block_лианозово                       45694 non-null  int8
#  185 geo_block_д. 1, к. 1                      45694 non-null  int8
#  186 geo_block_соколиная гора                  45694 non-null  int8
#  187 geo_block_богородское                     45694 non-null  int8
#  188 geo_block_ул бочкова                      45694 non-null  int8
#  189 geo_block_пр-кт маршала жукова            45694 non-null  int8
#  190 geo_block_вешняки                         45694 non-null  int8
#  191 geo_block_якиманка                        45694 non-null  int8
#  192 geo_block_северное тушино                 45694 non-null  int8
#  193 geo_block_нагорный                        45694 non-null  int8
#  194 geo_block_п. воскресенское                45694 non-null  int8
#  195 geo_block_б-р генерала карбышева          45694 non-null  int8
#  196 geo_block_савёловский                     45694 non-null  int8
#  197 geo_block_д. 32                           45694 non-null  int8
#  198 geo_block_ул земляной вал                 45694 non-null  int8
#  199 geo_block_арбат                           45694 non-null  int8
#  200 geo_block_академический                   45694 non-null  int8
#  201 geo_block_царицыно                        45694 non-null  int8
#  202 geo_block_коньково                        45694 non-null  int8
#  203 geo_block_п. первомайское                 45694 non-null  int8
#  204 geo_block_ул михайлова                    45694 non-null  int8
#  205 geo_block_ул нежинская                    45694 non-null  int8
#  206 geo_block_восточное измайлово             45694 non-null  int8
#  207 geo_block_д. 1, к. 3                      45694 non-null  int8
#  208 geo_block_ул арбат                        45694 non-null  int8
#  209 geo_block_пер холодильный                 45694 non-null  int8
#  210 geo_block_ул фадеева                      45694 non-null  int8
#  211 geo_block_ул юннатов                      45694 non-null  int8
#  212 geo_block_пер хилков                      45694 non-null  int8
#  213 geo_block_ул орджоникидзе                 45694 non-null  int8
#  214 geo_block_ул генерала глаголева           45694 non-null  int8
#  215 geo_block_д. говорово                     45694 non-null  int8
#  216 geo_block_проспект вернадского            45694 non-null  int8
#  217 geo_block_ул паршина                      45694 non-null  int8
#  218 geo_block_кузьминки                       45694 non-null  int8
#  219 geo_block_мещанский                       45694 non-null  int8
#  220 geo_block_покровское-стрешнево            45694 non-null  int8
#  221 geo_block_ул циолковского                 45694 non-null  int8
#  222 geo_block_нагатинский затон               45694 non-null  int8
#  223 geo_block_ул маршала катукова             45694 non-null  int8
#  224 geo_block_строгино                        45694 non-null  int8
#  225 geo_block_д. язово                        45694 non-null  int8
#  226 geo_block_пер богословский                45694 non-null  int8
#  227 geo_block_орехово-борисово северное       45694 non-null  int8
#  228 geo_block_бибирево                        45694 non-null  int8
#  229 geo_block_пер басманный                   45694 non-null  int8
#  230 geo_block_пл курского вокзала             45694 non-null  int8
#  231 geo_block_перово                          45694 non-null  int8
#  232 geo_block_сокол                           45694 non-null  int8
#  233 geo_block_ул адмирала макарова            45694 non-null  int8
#  234 geo_block_пер коробейников                45694 non-null  int8
#  235 geo_block_ул речников                     45694 non-null  int8
#  236 geo_block_москворечье-сабурово            45694 non-null  int8
#  237 geo_block_ясенево                         45694 non-null  int8
#  238 geo_block_г. щербинка                     45694 non-null  int8
#  239 geo_block_г. троицк                       45694 non-null  int8
#  240 geo_block_ул фабрициуса                   45694 non-null  int8
#  241 geo_block_д. ямонтово                     45694 non-null  int8
#  242 geo_block_ул усиевича                     45694 non-null  int8
#  243 geo_block_войковский                      45694 non-null  int8
#  244 geo_block_ул черняховского                45694 non-null  int8
#  245 geo_block_ул палиха                       45694 non-null  int8
#  246 geo_block_п. щаповское                    45694 non-null  int8
#  247 geo_block_ул демьяна бедного              45694 non-null  int8
#  248 geo_block_ул серпуховский вал             45694 non-null  int8
#  249 geo_block_южнопортовый                    45694 non-null  int8
#  250 geo_block_п. новофедоровское              45694 non-null  int8
#  251 geo_block_ул мельникова                   45694 non-null  int8
#  252 geo_block_пр-кт вернадского               45694 non-null  int8
#  253 geo_block_пер докучаев                    45694 non-null  int8
#  254 geo_block_ул софьи ковалевской            45694 non-null  int8
#  255 geo_block_сокольники                      45694 non-null  int8
#  256 geo_block_фили-давыдково                  45694 non-null  int8
#  257 geo_block_пр-кт 40 лет октября            45694 non-null  int8
#  258 geo_block_гагаринский                     45694 non-null  int8
#  259 geo_block_пер гороховский                 45694 non-null  int8
#  260 geo_block_пер тессинский                  45694 non-null  int8
#  261 geo_block_чертаново северное              45694 non-null  int8
#  262 geo_block_ул новая дорога                 45694 non-null  int8
#  263 geo_block_ул коминтерна                   45694 non-null  int8
#  264 geo_block_нагатино-садовники              45694 non-null  int8
#  265 geo_block_наб павелецкая                  45694 non-null  int8
#  266 geo_block_пер еропкинский                 45694 non-null  int8
#  267 geo_block_ул пресненский вал              45694 non-null  int8
#  268 geo_block_ул багрицкого                   45694 non-null  int8
#  269 geo_block_ул 40 лет октября               45694 non-null  int8
#  270 geo_block_п. дорожно-ремонтного пункта 3  45694 non-null  int8
#  271 geo_block_преображенское                  45694 non-null  int8
#  272 geo_block_д. 8                            45694 non-null  int8
#  273 geo_block_ул василисы кожиной             45694 non-null  int8
#  274 geo_block_ул покрышкина                   45694 non-null  int8
#  275 geo_block_пер даев                        45694 non-null  int8
#  276 geo_block_ул комдива орлова               45694 non-null  int8
#  277 geo_block_го троицк                       45694 non-null  int8
#  278 geo_block_можайский                       45694 non-null  int8
#  279 geo_block_ул академика анохина            45694 non-null  int8
#  280 geo_block_ул скульптора мухиной           45694 non-null  int8
#  281 geo_block_0                               45694 non-null  object
#  282 geo_block_1                               45694 non-null  object
#  283 geo_block_2                               45694 non-null  object
#  284 geo_block_3                               45694 non-null  object
#  285 geo_block_4                               45694 non-null  object
#  286 geo_block_5                               45694 non-null  object
#  287 geo_block_0_cat                           45694 non-null  int8
#  288 geo_block_1_cat                           45694 non-null  int16
#  289 geo_block_2_cat                           45694 non-null  int16
#  290 geo_block_3_cat                           45694 non-null  int16
#  291 geo_block_4_cat                           45694 non-null  int8
#  292 geo_block_5_cat                           45694 non-null  int8
#  293 owner_len                                 45694 non-null  int8
#  294 owner_cnt                                 45694 non-null  int8
#  295 security_wrd_cnt                          45694 non-null  int8
#  296 security_len                              45694 non-null  int16
#  297 security_provided                         45694 non-null  int8
#  298 security_area                             45694 non-null  int8
#  299 security_closed                           45694 non-null  int8
#  300 security_video                            45694 non-null  int8
#  301 security_surveillance                     45694 non-null  int8
#  302 security_concierge                        45694 non-null  int8
#  303 security_the                              45694 non-null  int8
#  304 security_fenced                           45694 non-null  int8
#  305 security_security                         45694 non-null  int8
#  306 security_yes                              45694 non-null  int8
#  307 security_system                           45694 non-null  int8
#  308 security_access                           45694 non-null  int8
#  309 security_control                          45694 non-null  int8
#  310 security_and                              45694 non-null  int8
#  311 security_clock                            45694 non-null  int8
#  312 security_round                            45694 non-null  int8
#  313 security_guarded                          45694 non-null  int8
#  314 security_of                               45694 non-null  int8
#  315 security_perimeter                        45694 non-null  int8
#  316 security_barrier                          45694 non-null  int8
#  317 fact_Building type:_mean                  45694 non-null  int8
#  318 fact_Building type:_median                45694 non-null  int8
#  319 fact_Object type:_mean                    45694 non-null  int8
#  320 fact_Object type:_median                  45694 non-null  int8
#  321 fact_Ad type:_mean                        45694 non-null  int8
#  322 fact_Ad type:_median                      45694 non-null  int8
#  323 OH_Commission agent:_-1                   45694 non-null  int8
#  324 OH_Commission agent:_no fee               45694 non-null  int8
#  325 fact_Construction phase:_mean             45694 non-null  int8
#  326 fact_Construction phase:_median           45694 non-null  int8
#  327 fact_Housing class:_mean                  45694 non-null  int8
#  328 fact_Housing class:_median                45694 non-null  int8
#  329 OH_Elevator:_-1                           45694 non-null  int8
#  330 OH_Elevator:_yes                          45694 non-null  int8
#  331 fact_Bathroom type:_mean                  45694 non-null  int8
#  332 fact_Bathroom type:_median                45694 non-null  int8
#  333 fact_Balcony type:_mean                   45694 non-null  int8
#  334 fact_Balcony type:_median                 45694 non-null  int8
#  335 OH_Mortgage possible:_-1                  45694 non-null  int8
#  336 OH_Mortgage possible:_yes                 45694 non-null  int8
#  337 fact_The view from the window:_mean       45694 non-null  int8
#  338 fact_The view from the window:_median     45694 non-null  int8
#  339 OH_Garbage chute:_-1                      45694 non-null  int8
#  340 OH_Garbage chute:_yes                     45694 non-null  int8
#  341 fact_Repair:_mean                         45694 non-null  int8
#  342 fact_Repair:_median                       45694 non-null  int8
#  343 OH_Fridge:_-1                             45694 non-null  int8
#  344 OH_Fridge:_yes                            45694 non-null  int8
#  345 OH_Phone:_-1                              45694 non-null  int8
#  346 OH_Phone:_yes                             45694 non-null  int8
#  347 OH_Furniture:_-1                          45694 non-null  int8
#  348 OH_Furniture:_yes                         45694 non-null  int8
#  349 OH_Free layout:_-1                        45694 non-null  int8
#  350 OH_Free layout:_yes                       45694 non-null  int8
#  351 OH_It is possible to bargain:_-1          45694 non-null  int8
#  352 OH_It is possible to bargain:_yes         45694 non-null  int8
#  353 fact_Floor covering:_mean                 45694 non-null  int8
#  354 fact_Floor covering:_median               45694 non-null  int8
#  355 fact_Room type:_mean                      45694 non-null  int8
#  356 fact_Room type:_median                    45694 non-null  int8
#  357 OH_Internet:_-1                           45694 non-null  int8
#  358 OH_Internet:_yes                          45694 non-null  int8
#  359 OH_Kitchen furniture:_-1                  45694 non-null  int8
#  360 OH_Kitchen furniture:_yes                 45694 non-null  int8
#  361 OH_TV:_-1                                 45694 non-null  int8
#  362 OH_TV:_yes                                45694 non-null  int8
#  363 OH_Washing machine:_-1                    45694 non-null  int8
#  364 OH_Washing machine:_yes                   45694 non-null  int8
#  365 fact_Foundation type:_mean                45694 non-null  int8
#  366 fact_Foundation type:_median              45694 non-null  int8
#  367 fact_Overlap type:_mean                   45694 non-null  int8
#  368 fact_Overlap type:_median                 45694 non-null  int8
#  369 fact_Type of the building:_mean           45694 non-null  int8
#  370 fact_Type of the building:_median         45694 non-null  int8
#  371 OH_Playground:_-1                         45694 non-null  int8
#  372 OH_Playground:_yes                        45694 non-null  int8
#  373 OH_Class:_-1                              45694 non-null  int8
#  374 OH_Class:_elite real estate               45694 non-null  int8
#  375 fact_date_month_mean                      45694 non-null  int8
#  376 fact_date_month_median                    45694 non-null  int8
# dtypes: float64(2), int16(5), int8(342), object(28)
# memory usage: 26.1+ MB

# %%
# # correlation
# corrmat = train.corr(method='spearman')

# %%
# # price zoomed correlation 

# zoomed_correlation = corrmat.sort_values(by='price')['price']

# zoomed_correlation[(zoomed_correlation < -0.2) | (zoomed_correlation > 0.2)]

# %%
for col in [x for x in test.columns if test[x].dtype != 'O']:
    if test[col].max() == test[col].min():
        print(col, '\n', test[col].max(), test[col].min(), '\n')
# Out:
# breadcrumbs_москва
#  1 1
#
# geo_block_5
#  -1 -1
#
# geo_block_5_cat
#  -1 -1

# %%
train.shape
# Out:
# (45694, 377)

# %%
test.shape
# Out:
# (22667, 376)

# %% [markdown]
# ## Model xgboost + hyperopt

# %%
# prepare input
black_list=['price', 'id', 'fact_Type of the building:_mean', 'fact_Type of the building:_median']
feats = [z for z in [x for x in train.columns if train[x].dtype != 'O'] if z not in black_list] #tu można też select_dtypes


# prepare X y
X = train[feats].values
y = train["price"].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2021)

# %%
# whats the target variable distributtion ?
plot.hist(y_train, bins=1000);
# plot.hist(y_test, bins=1000);

# %%
# target distribution after log ?
plot.hist(np.log(y_train), bins=1000);

# %%
# make log from target
target_log = True

if target_log:
    y_train = np.log(y_train)
    y_test = np.log(y_test)

# %%
# prepare metrics
def mae_log_eval(y_log_pred, dtrain):
    y_log_true = dtrain.get_label()
    
    shift = 0
    y_true = np.exp(y_log_true) - shift
    y_pred = np.exp(y_log_pred) - shift
    
    return 'mae', mean_absolute_error(y_true, y_pred)

def fair_obj(y_true, preds):
    labels = y_true
    x = (preds - labels)
    fair_constant = 0.5
    den = abs(x) + fair_constant
    
    grad = fair_constant * x / den
    hess = fair_constant * fair_constant / (den * den)
    
    return grad, hess

# %%
# hyperopt
# terminated by user, already have params from this cell

def objective(space):
    xgb_params = {
        'max_depth': int(space['max_depth']),
        'colsample_bytree': space['colsample_bytree'],
        'learning_rate': space['learning_rate'],
#          'subsample': space['subsample'],
         'random_state': 20, 
#          'min_child_weight': int(space['min_child_weight']),
        'reg_alpha': space['reg_alpha'],
        'reg_lambda':space['reg_lambda'],
#         'n_estimators': int(space['n_estimators']),
        'tree_method': 'gpu_hist',
    }

    model = xgb.XGBRegressor(**xgb_params)
    
    model.fit(X_train, y_train,   
              eval_metric = mae_log_eval,
              verbose=False)
    
    y_pred = model.predict(X_test)

    if target_log:
        y_pred = np.exp(y_pred)
        y_pred[y_pred < 0] = 1e-6  # for minus zero values

    score = mean_absolute_error(y_test, y_pred)

    return {'loss': score, 'status': STATUS_OK}


space = {
    'max_depth': hp.quniform('x_max_depth', 2, 20, 1),
    'colsample_bytree': hp.uniform('x_colsample_bytree', 0.5, 1.),
    'learning_rate': hp.uniform('x_learning_rate', 0.01, 1),
#     'subsample': hp.uniform ('x_subsample', 0.7, 1.),
#     'min_child_weight': hp.quniform ('x_min_child_weight', 1, 10, 1),
    'reg_alpha': hp.loguniform('x_reg_alpha', 0., 1.),
    'reg_lambda': hp.uniform('x_reg_lambda', 0.7, 1.),
#     'n_estimators': hp.quniform ('x_n_estimators', 10, 1300, 10),
}

trials = Trials()
best_params = fmin(fn=objective,
                   space=space,
                   algo=partial(tpe.suggest, n_startup_jobs=40),
                   max_evals=100,
                   trials=trials)


print("The best params: ", best_params)


# # dump best params to a file
# import pickle
# # save
# pickle.dump(trials, open("output/kaggle/working/my_trials.pkl", "wb"))
# # load
# trials = pickle.load(open("output/kaggle/working/my_trials.pkl", "rb"))

# %%
best_params

# %%
# prepare X y
X = train[feats].values
y = train["price"].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2021)

target_log = True

shift = 0
if target_log:
    y_train_log = np.log(y_train) + shift
    y_test_log = np.log(y_test) + shift

# %%
# Model
# kaggle: 4.90

print('y_train', np.round(np.percentile(y_train, [1,5,25,50,75,95,99]),2))


xgb_params = {'objective' : fair_obj,
              'colsample_bytree': 0.639338169696854,
              'learning_rate': 0.010004061027776059,
              'max_depth': 17,
              'reg_alpha': 1.1538760116889881,
              'reg_lambda': 0.9937596019610064,
              'min_child_weight': 6,
              'n_estimators': 1200,
              'subsample': 0.8762074509846408,
              'tree_method': 'gpu_hist',
              'random_state': 20}

model = xgb.XGBRegressor(**xgb_params)

eval_set = [(X_train, y_train_log), (X_test, y_test_log)]

model.fit(X_train, y_train_log, \
         eval_metric = mae_log_eval,
         eval_set = eval_set, \
         verbose = 20)


print("predict - NEW METRIC")

if target_log:
    
    y_pred_log = model.predict(X_test) - shift
    y_pred_log[ y_pred_log < 0 ] = 1e-6 # for sub zero values
    y_pred = np.exp( y_pred_log )

score = mean_absolute_error(y_test, y_pred)

print('validation score - NEW OBJ: {}'.format(score))



print("save file")
test_price_log = model.predict(test[feats].values) - shift
test['price'] = np.exp(test_price_log)
test['id'] = test['id'].astype('int32')
test[ ['id', 'price'] ].to_csv('newmetric_3_check.csv', index=False)

plot.figure(figsize = (20,10))
train[ train.price < np.percentile( train.price, 95 ) ]['price'].hist(bins=30, color='blue')
test[ test.price < np.percentile( test.price, 95 ) ]['price'].hist(bins=30, color='red')
plot.show()
# Out:
# y_train [  3.41   4.83   7.15   9.91  15.36  47.18 158.34]
# [0]	validation_0-rmse:1.97267	validation_0-mae:15.71067	validation_1-rmse:1.97578	validation_1-mae:15.26638
# [20]	validation_0-rmse:1.05968	validation_0-mae:12.76464	validation_1-rmse:1.05373	validation_1-mae:12.28414
# [40]	validation_0-rmse:0.74305	validation_0-mae:10.53810	validation_1-rmse:0.73465	validation_1-mae:10.01800
# [60]	validation_0-rmse:0.58849	validation_0-mae:9.00899	validation_1-rmse:0.57992	validation_1-mae:8.48081
# [80]	validation_0-rmse:0.49888	validation_0-mae:7.94929	validation_1-rmse:0.49106	validation_1-mae:7.43051
# [100]	validation_0-rmse:0.44109	validation_0-mae:7.18911	validation_1-rmse:0.43448	validation_1-mae:6.68257
# [120]	validation_0-rmse:0.40181	validation_0-mae:6.63864	validation_1-rmse:0.39666	validation_1-mae:6.14858
# [140]	validation_0-rmse:0.37444	validation_0-mae:6.23989	validation_1-rmse:0.37097	validation_1-mae:5.77593
# [160]	validation_0-rmse:0.35494	validation_0-mae:5.94783	validation_1-rmse:0.35313	validation_1-mae:5.50865
# [180]	validation_0-rmse:0.34059	validation_0-mae:5.72731	validation_1-rmse:0.34040	validation_1-mae:5.32045
# [200]	validation_0-rmse:0.32988	validation_0-mae:5.55810	validation_1-rmse:0.33136	validation_1-mae:5.18697
# [220]	validation_0-rmse:0.32174	validation_0-mae:5.42634	validation_1-rmse:0.32468	validation_1-mae:5.08632
# [240]	validation_0-rmse:0.31536	validation_0-mae:5.32165	validation_1-rmse:0.31988	validation_1-mae:5.01108
# [260]	validation_0-rmse:0.31041	validation_0-mae:5.23701	validation_1-rmse:0.31634	validation_1-mae:4.95388
# [280]	validation_0-rmse:0.30627	validation_0-mae:5.16749	validation_1-rmse:0.31362	validation_1-mae:4.91028
# [300]	validation_0-rmse:0.30280	validation_0-mae:5.10797	validation_1-rmse:0.31154	validation_1-mae:4.87877
# [320]	validation_0-rmse:0.29986	validation_0-mae:5.05699	validation_1-rmse:0.30990	validation_1-mae:4.85583
# [340]	validation_0-rmse:0.29723	validation_0-mae:5.01162	validation_1-rmse:0.30855	validation_1-mae:4.83696
# [360]	validation_0-rmse:0.29497	validation_0-mae:4.97328	validation_1-rmse:0.30743	validation_1-mae:4.82036
# [380]	validation_0-rmse:0.29286	validation_0-mae:4.93632	validation_1-rmse:0.30644	validation_1-mae:4.80662
# [400]	validation_0-rmse:0.29098	validation_0-mae:4.90373	validation_1-rmse:0.30565	validation_1-mae:4.79556
# [420]	validation_0-rmse:0.28919	validation_0-mae:4.87290	validation_1-rmse:0.30484	validation_1-mae:4.78367
# [440]	validation_0-rmse:0.28765	validation_0-mae:4.84770	validation_1-rmse:0.30425	validation_1-mae:4.77649
# [460]	validation_0-rmse:0.28602	validation_0-mae:4.81952	validation_1-rmse:0.30363	validation_1-mae:4.76812
# [480]	validation_0-rmse:0.28468	validation_0-mae:4.79575	validation_1-rmse:0.30311	validation_1-mae:4.76149
# [500]	validation_0-rmse:0.28334	validation_0-mae:4.77332	validation_1-rmse:0.30265	validation_1-mae:4.75589
# [520]	validation_0-rmse:0.28209	validation_0-mae:4.75178	validation_1-rmse:0.30227	validation_1-mae:4.75170
# [540]	validation_0-rmse:0.28085	validation_0-mae:4.73102	validation_1-rmse:0.30184	validation_1-mae:4.74651
# [560]	validation_0-rmse:0.27966	validation_0-mae:4.70969	validation_1-rmse:0.30143	validation_1-mae:4.74130
# [580]	validation_0-rmse:0.27855	validation_0-mae:4.68990	validation_1-rmse:0.30105	validation_1-mae:4.73615
# [600]	validation_0-rmse:0.27731	validation_0-mae:4.66890	validation_1-rmse:0.30062	validation_1-mae:4.73143
# [620]	validation_0-rmse:0.27630	validation_0-mae:4.65117	validation_1-rmse:0.30031	validation_1-mae:4.72727
# [640]	validation_0-rmse:0.27522	validation_0-mae:4.63278	validation_1-rmse:0.29998	validation_1-mae:4.72332
# [660]	validation_0-rmse:0.27421	validation_0-mae:4.61489	validation_1-rmse:0.29969	validation_1-mae:4.71977
# [680]	validation_0-rmse:0.27321	validation_0-mae:4.59752	validation_1-rmse:0.29939	validation_1-mae:4.71512
# [700]	validation_0-rmse:0.27220	validation_0-mae:4.58080	validation_1-rmse:0.29910	validation_1-mae:4.71163
# [720]	validation_0-rmse:0.27121	validation_0-mae:4.56365	validation_1-rmse:0.29881	validation_1-mae:4.70777
# [740]	validation_0-rmse:0.27033	validation_0-mae:4.54769	validation_1-rmse:0.29861	validation_1-mae:4.70455
# [760]	validation_0-rmse:0.26943	validation_0-mae:4.53136	validation_1-rmse:0.29836	validation_1-mae:4.70164
# [780]	validation_0-rmse:0.26847	validation_0-mae:4.51396	validation_1-rmse:0.29815	validation_1-mae:4.69936
# [800]	validation_0-rmse:0.26764	validation_0-mae:4.49950	validation_1-rmse:0.29796	validation_1-mae:4.69711
# [820]	validation_0-rmse:0.26687	validation_0-mae:4.48568	validation_1-rmse:0.29779	validation_1-mae:4.69548
# [840]	validation_0-rmse:0.26610	validation_0-mae:4.47183	validation_1-rmse:0.29759	validation_1-mae:4.69262
# [860]	validation_0-rmse:0.26516	validation_0-mae:4.45465	validation_1-rmse:0.29739	validation_1-mae:4.69144
# [880]	validation_0-rmse:0.26417	validation_0-mae:4.43783	validation_1-rmse:0.29717	validation_1-mae:4.68907
# [900]	validation_0-rmse:0.26338	validation_0-mae:4.42345	validation_1-rmse:0.29697	validation_1-mae:4.68705
# [920]	validation_0-rmse:0.26245	validation_0-mae:4.40756	validation_1-rmse:0.29677	validation_1-mae:4.68378
# [940]	validation_0-rmse:0.26165	validation_0-mae:4.39321	validation_1-rmse:0.29659	validation_1-mae:4.68185
# [960]	validation_0-rmse:0.26082	validation_0-mae:4.37801	validation_1-rmse:0.29638	validation_1-mae:4.67959
# [980]	validation_0-rmse:0.26000	validation_0-mae:4.36349	validation_1-rmse:0.29621	validation_1-mae:4.67731
# [1000]	validation_0-rmse:0.25918	validation_0-mae:4.34853	validation_1-rmse:0.29606	validation_1-mae:4.67587
# [1020]	validation_0-rmse:0.25837	validation_0-mae:4.33458	validation_1-rmse:0.29586	validation_1-mae:4.67291
# [1040]	validation_0-rmse:0.25761	validation_0-mae:4.32102	validation_1-rmse:0.29573	validation_1-mae:4.67155
# [1060]	validation_0-rmse:0.25686	validation_0-mae:4.30776	validation_1-rmse:0.29560	validation_1-mae:4.67032
# [1080]	validation_0-rmse:0.25613	validation_0-mae:4.29453	validation_1-rmse:0.29548	validation_1-mae:4.66877
# [1100]	validation_0-rmse:0.25545	validation_0-mae:4.28153	validation_1-rmse:0.29533	validation_1-mae:4.66717
# [1120]	validation_0-rmse:0.25468	validation_0-mae:4.26755	validation_1-rmse:0.29523	validation_1-mae:4.66552
# [1140]	validation_0-rmse:0.25392	validation_0-mae:4.25343	validation_1-rmse:0.29509	validation_1-mae:4.66317
# [1160]	validation_0-rmse:0.25323	validation_0-mae:4.24065	validation_1-rmse:0.29498	validation_1-mae:4.66080
# [1180]	validation_0-rmse:0.25249	validation_0-mae:4.22686	validation_1-rmse:0.29490	validation_1-mae:4.66005
# [1199]	validation_0-rmse:0.25188	validation_0-mae:4.21547	validation_1-rmse:0.29480	validation_1-mae:4.65815
# predict - NEW METRIC
# validation score - NEW OBJ: 4.658151171884532
# save file
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +

# %%
# plot learning curve
plot.title("Learning curve MAE")
plot.xlabel("# estimators")
plot.ylabel("Error")
plot.plot( model.evals_result_['validation_0']['mae'], label='train' )
plot.plot( model.evals_result_['validation_1']['mae'], label='test' )
plot.legend(loc='best')
plot.show()

plot.title("Learning curve RMSE")
plot.xlabel("# estimators")
plot.ylabel("Error")
plot.plot( model.evals_result_['validation_0']['rmse'], label='train' )
plot.plot( model.evals_result_['validation_1']['rmse'], label='test' )
plot.legend(loc='best')
plot.show()

# %% [markdown]
# ### Feature importance

# %%
# !pip install xgbfir
# Out:
# Collecting xgbfir
#   Downloading xgbfir-0.3.1-py2.py3-none-any.whl (8.3 kB)
# Collecting xlsxwriter>=0.9.3
#   Downloading XlsxWriter-1.4.3-py2.py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 4.4 MB/s eta 0:00:01
# Installing collected packages: xlsxwriter, xgbfir
# Successfully installed xgbfir-0.3.1 xlsxwriter-1.4.3

# %%
# SAVE FEATURE IMPORTANCE
import xgbfir
target_log = True

# prepare input
black_list=['price', 'id', 'fact_Type of the building:_mean', 'fact_Type of the building:_median']
feats = [z for z in [x for x in train.columns if train[x].dtype != 'O'] if z not in black_list] #tu można też select_dtypes


# prepare X y
X = train[feats].values
y = train["price"].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=2)

if target_log:
    y_train = np.log(y_train)
    
print("train model")
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=feats)
# dtest = xgb.DMatrix(y_train.reshape((1, -1)))

# evallist = [(dtest, 'test'), (dtrain, 'train')]

xgb_params = {'max_depth':10, 'n_estimators':70, 'learning_rate':0.1, 'random_state':3}

# model = xgb.XGBRegressor(max_depth=10, n_estimators=70, learning_rate=0.1, random_state=3)
model = xgb.train(xgb_params, dtrain, \
                  num_boost_round=60, \
#                   early_stopping_rounds=50, \
                  maximize=False, verbose_eval=10)
# model.fit(X_train, y_train)

# plot
fig, ax = plot.subplots(3,1,figsize=(10,30))

nfeats = 35
importance_types = ['weight', 'cover', 'gain']

for i, imp_i in enumerate(importance_types):
    xgb.plot_importance(model, ax=ax[i], max_num_features=nfeats
                    , importance_type=imp_i
                    , xlabel=imp_i)

# save xgbfir file to excel
xgbfir.saveXgbFI(model, OutputXlsxFile='feature importance.xlsx')
# Out:
# train model
# [00:11:21] WARNING: ../src/learner.cc:573:
# Parameters: { "n_estimators" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
